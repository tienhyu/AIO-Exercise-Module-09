# %% [markdown]
# # **1. Setup & Library Imports**

# %%
import os
import math
import torch
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch import nn
from PIL import Image
from tqdm import tqdm
from diffusers import AutoencoderKL
from torch.nn import functional as F
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from transformers import CLIPTokenizer, CLIPTextModel
import torch.optim.lr_scheduler as lr_scheduler
from torch.amp import GradScaler, autocast
# Out:
# 2025-04-14 07:04:28.452090: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744614268.694967      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744614268.759375      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)
    print(f"Seed set to {seed}")

set_seed()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# Seed set to 42
# cuda

# %%
# Download emoji dataset
# https://drive.google.com/file/d/15Z_F4Dwgb3NLqEGnVMUEJqyxXgW7Gx-h/view?usp=sharing
# !gdown 18RbI4n62UQ_8pGkHcYoaUuAbOaRWYKk9
# !unzip panda_crawled_data.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18RbI4n62UQ_8pGkHcYoaUuAbOaRWYKk9
# To: /kaggle/working/panda_crawled_data.zip
# 100%|██████████████████████████████████████| 15.5M/15.5M [00:00<00:00, 39.0MB/s]
# Archive:  panda_crawled_data.zip
#    creating: images/
#   inflating: images/Panda_0000001.jpg
#   inflating: images/Panda_0000002.jpg
#   inflating: images/Panda_0000003.jpg
#   inflating: images/Panda_0000004.jpg
#   inflating: images/Panda_0000005.jpg
#   inflating: images/Panda_0000006.jpg
#   inflating: images/Panda_0000007.jpg
#   inflating: images/Panda_0000008.jpg
#   inflating: images/Panda_0000009.jpg
#   inflating: images/Panda_0000010.jpg
#   inflating: images/Panda_0000011.jpg
#   inflating: images/Panda_0000012.jpg
#   inflating: images/Panda_0000013.jpg
#   inflating: images/Panda_0000014.jpg
#   inflating: images/Panda_0000015.jpg
#   inflating: images/Panda_0000016.jpg
#   inflating: images/Panda_0000017.jpg
#   inflating: images/Panda_0000018.jpg
#   inflating: images/Panda_0000019.jpg
#   inflating: images/Panda_0000020.jpg
#   inflating: images/Panda_0000021.jpg
#   inflating: images/Panda_0000022.jpg
#   inflating: images/Panda_0000023.jpg
#   inflating: images/Panda_0000024.jpg
#   inflating: images/Panda_0000025.jpg
#   inflating: images/Panda_0000026.jpg
#   inflating: images/Panda_0000027.jpg
#   inflating: images/Panda_0000028.jpg
#   inflating: images/Panda_0000029.jpg
#   inflating: images/Panda_0000030.jpg
#   inflating: images/Panda_0000031.jpg
#   inflating: images/Panda_0000032.jpg
#   inflating: images/Panda_0000033.jpg
#   inflating: images/Panda_0000034.jpg
#   inflating: images/Panda_0000035.jpg
#   inflating: images/Panda_0000036.jpg
#   inflating: images/Panda_0000037.jpg
#   inflating: images/Panda_0000038.jpg
#   inflating: images/Panda_0000039.jpg
#   inflating: images/Panda_0000040.jpg
#   inflating: images/Panda_0000041.jpg
#   inflating: images/Panda_0000042.jpg
#   inflating: images/Panda_0000043.jpg
#   inflating: images/Panda_0000044.jpg
#   inflating: images/Panda_0000045.jpg
#   inflating: images/Panda_0000046.jpg
#   inflating: images/Panda_0000048.jpg
#   inflating: images/Panda_0000050.jpg
#   inflating: images/Panda_0000051.jpg
#   inflating: images/Panda_0000052.jpg
#   inflating: images/Panda_0000053.jpg
#   inflating: images/Panda_0000054.jpg
#   inflating: images/Panda_0000055.jpg
#   inflating: images/Panda_0000056.jpg
#   inflating: images/Panda_0000058.jpg
#   inflating: images/Panda_0000059.jpg
#   inflating: images/Panda_0000060.jpg
#   inflating: images/Panda_0000061.jpg
#   inflating: images/Panda_0000062.jpg
#   inflating: images/Panda_0000063.jpg
#   inflating: images/Panda_0000064.jpg
#   inflating: images/Panda_0000065.jpg
#   inflating: images/Panda_0000066.jpg
#   inflating: images/Panda_0000067.jpg
#   inflating: images/Panda_0000068.jpg
#   inflating: images/Panda_0000069.jpg
#   inflating: images/Panda_0000070.jpg
#   inflating: images/Panda_0000071.jpg
#   inflating: images/Panda_0000072.jpg
#   inflating: images/Panda_0000073.jpg
#   inflating: images/Panda_0000074.jpg
#   inflating: images/Panda_0000076.jpg
#   inflating: images/Panda_0000077.jpg
#   inflating: images/Panda_0000078.jpg
#   inflating: images/Panda_0000079.jpg
#   inflating: images/Panda_0000080.jpg
#   inflating: images/Panda_0000081.jpg
#   inflating: images/Panda_0000082.jpg
#   inflating: images/Panda_0000084.jpg
#   inflating: images/Panda_0000085.jpg
#   inflating: images/Panda_0000086.jpg
#   inflating: images/Panda_0000087.jpg
#   inflating: images/Panda_0000088.jpg
#   inflating: images/Panda_0000090.jpg
#   inflating: images/Panda_0000091.jpg
#   inflating: images/Panda_0000092.jpg
#   inflating: images/Panda_0000093.jpg
#   inflating: images/Panda_0000094.jpg
#   inflating: images/Panda_0000095.jpg
#   inflating: images/Panda_0000096.jpg
#   inflating: images/Panda_0000097.jpg
#   inflating: images/Panda_0000098.jpg
#   inflating: images/Panda_0000099.jpg
#   inflating: images/Panda_0000100.jpg
#   inflating: images/Panda_0000102.jpg
#   inflating: images/Panda_0000103.jpg
#   inflating: images/Panda_0000104.jpg
#   inflating: images/Panda_0000105.jpg
#   inflating: images/Panda_0000106.jpg
#   inflating: images/Panda_0000109.jpg
#   inflating: images/Panda_0000110.jpg
#   inflating: images/Panda_0000111.jpg
#   inflating: images/Panda_0000112.jpg
#   inflating: images/Panda_0000113.jpg
#   inflating: images/Panda_0000114.jpg
#   inflating: images/Panda_0000115.jpg
#   inflating: images/Panda_0000118.jpg
#   inflating: images/Panda_0000119.jpg
#   inflating: images/Panda_0000120.jpg
#   inflating: images/Panda_0000121.jpg
#   inflating: images/Panda_0000122.jpg
#   inflating: images/Panda_0000123.jpg
#   inflating: images/Panda_0000124.jpg
#   inflating: images/Panda_0000125.jpg
#   inflating: images/Panda_0000126.jpg
#   inflating: images/Panda_0000127.jpg
#   inflating: images/Panda_0000128.jpg
#   inflating: images/Panda_0000129.jpg
#   inflating: images/Panda_0000130.jpg
#   inflating: images/Panda_0000131.jpg
#   inflating: images/Panda_0000134.jpg
#   inflating: images/Panda_0000136.jpg
#   inflating: images/Panda_0000137.jpg
#   inflating: images/Panda_0000138.jpg
#   inflating: images/Panda_0000139.jpg
#   inflating: images/Panda_0000140.jpg
#   inflating: images/Panda_0000141.jpg
#   inflating: images/Panda_0000142.jpg
#   inflating: images/Panda_0000143.jpg
#   inflating: images/Panda_0000144.jpg
#   inflating: images/Panda_0000145.jpg
#   inflating: images/Panda_0000147.jpg
#   inflating: images/Panda_0000148.jpg
#   inflating: images/Panda_0000149.jpg
#   inflating: images/Panda_0000151.jpg
#   inflating: images/Panda_0000153.jpg
#   inflating: images/Panda_0000154.jpg
#   inflating: images/Panda_0000155.jpg
#   inflating: images/Panda_0000157.jpg
#   inflating: images/Panda_0000158.jpg
#   inflating: images/Panda_0000159.jpg
#   inflating: images/Panda_0000160.jpg
#   inflating: images/Panda_0000161.jpg
#   inflating: images/Panda_0000162.jpg
#   inflating: images/Panda_0000163.jpg
#   inflating: images/Panda_0000165.jpg
#   inflating: images/Panda_0000166.jpg
#   inflating: images/Panda_0000167.jpg
#   inflating: images/Panda_0000168.jpg
#   inflating: images/Panda_0000169.jpg
#   inflating: images/Panda_0000170.jpg
#   inflating: images/Panda_0000171.jpg
#   inflating: images/Panda_0000172.jpg
#   inflating: images/Panda_0000173.jpg
#   inflating: images/Panda_0000174.jpg
#   inflating: images/Panda_0000175.jpg
#   inflating: images/Panda_0000176.jpg
#   inflating: images/Panda_0000177.jpg
#   inflating: images/Panda_0000178.jpg
#   inflating: images/Panda_0000179.jpg
#   inflating: images/Panda_0000180.jpg
#   inflating: images/Panda_0000181.jpg
#   inflating: images/Panda_0000183.jpg
#   inflating: images/Panda_0000184.jpg
#   inflating: images/Panda_0000186.jpg
#   inflating: images/Panda_0000187.jpg
#   inflating: images/Panda_0000188.jpg
#   inflating: images/Panda_0000189.jpg
#   inflating: images/Panda_0000190.jpg
#   inflating: images/Panda_0000192.jpg
#   inflating: images/Panda_0000193.jpg
#   inflating: images/Panda_0000194.jpg
#   inflating: images/Panda_0000195.jpg
#   inflating: images/Panda_0000196.jpg
#   inflating: images/Panda_0000197.jpg
#   inflating: images/Panda_0000198.jpg
#   inflating: images/Panda_0000199.jpg
#   inflating: images/Panda_0000200.jpg
#   inflating: images/Panda_0000201.jpg
#   inflating: images/Panda_0000203.jpg
#   inflating: images/Panda_0000204.jpg
#   inflating: images/Panda_0000205.jpg
#   inflating: images/Panda_0000206.jpg
#   inflating: images/Panda_0000208.jpg
#   inflating: images/Panda_0000209.jpg
#   inflating: images/Panda_0000210.jpg
#   inflating: images/Panda_0000211.jpg
#   inflating: images/Panda_0000212.jpg
#   inflating: images/Panda_0000213.jpg
#   inflating: images/Panda_0000214.jpg
#   inflating: images/Panda_0000215.jpg
#   inflating: images/Panda_0000216.jpg
#   inflating: images/Panda_0000217.jpg
#   inflating: images/Panda_0000218.jpg
#   inflating: images/Panda_0000219.jpg
#   inflating: images/Panda_0000220.jpg
#   inflating: images/Panda_0000221.jpg
#   inflating: images/Panda_0000223.jpg
#   inflating: images/Panda_0000224.jpg
#   inflating: images/Panda_0000225.jpg
#   inflating: images/Panda_0000226.jpg
#   inflating: images/Panda_0000228.jpg
#   inflating: images/Panda_0000230.jpg
#   inflating: images/Panda_0000231.jpg
#   inflating: images/Panda_0000232.jpg
#   inflating: images/Panda_0000233.jpg
#   inflating: images/Panda_0000234.jpg
#   inflating: images/Panda_0000236.jpg
#   inflating: images/Panda_0000237.jpg
#   inflating: images/Panda_0000238.jpg
#   inflating: images/Panda_0000239.jpg
#   inflating: images/Panda_0000240.jpg
#   inflating: images/Panda_0000241.jpg
#   inflating: images/Panda_0000242.jpg
#   inflating: images/Panda_0000243.jpg
#   inflating: images/Panda_0000244.jpg
#   inflating: images/Panda_0000245.jpg
#   inflating: images/Panda_0000246.jpg
#   inflating: images/Panda_0000247.jpg
#   inflating: images/Panda_0000248.jpg
#   inflating: images/Panda_0000249.jpg
#   inflating: images/Panda_0000250.jpg
#   inflating: images/Panda_0000251.jpg
#   inflating: images/Panda_0000252.jpg
#   inflating: images/Panda_0000253.jpg
#   inflating: images/Panda_0000254.jpg
#   inflating: images/Panda_0000255.jpg
#   inflating: images/Panda_0000256.jpg
#   inflating: images/Panda_0000257.jpg
#   inflating: images/Panda_0000258.jpg
#   inflating: images/Panda_0000259.jpg
#   inflating: images/Panda_0000260.jpg
#   inflating: images/Panda_0000261.jpg
#   inflating: images/Panda_0000262.jpg
#   inflating: images/Panda_0000263.jpg
#   inflating: images/Panda_0000264.jpg
#   inflating: images/Panda_0000265.jpg
#   inflating: images/Panda_0000266.jpg
#   inflating: images/Panda_0000267.jpg
#   inflating: images/Panda_0000268.jpg
#   inflating: images/Panda_0000269.jpg
#   inflating: images/Panda_0000270.jpg
#   inflating: images/Panda_0000271.jpg
#   inflating: images/Panda_0000272.jpg
#   inflating: images/Panda_0000273.jpg
#   inflating: images/Panda_0000274.jpg
#   inflating: images/Panda_0000275.jpg
#   inflating: images/Panda_0000276.jpg
#   inflating: images/Panda_0000277.jpg
#   inflating: images/Panda_0000278.jpg
#   inflating: images/Panda_0000279.jpg
#   inflating: images/Panda_0000280.jpg
#   inflating: images/Panda_0000281.jpg
#   inflating: images/Panda_0000282.jpg
#   inflating: images/Panda_0000283.jpg
#   inflating: images/Panda_0000284.jpg
#   inflating: images/Panda_0000285.jpg
#   inflating: images/Panda_0000287.jpg
#   inflating: images/Panda_0000288.jpg
#   inflating: images/Panda_0000289.jpg
#   inflating: images/Panda_0000290.jpg
#   inflating: images/Panda_0000291.jpg
#   inflating: images/Panda_0000292.jpg
#   inflating: images/Panda_0000293.jpg
#   inflating: images/Panda_0000294.jpg
#   inflating: images/Panda_0000295.jpg
#   inflating: images/Panda_0000296.jpg
#   inflating: images/Panda_0000297.jpg
#   inflating: images/Panda_0000298.jpg
#   inflating: images/Panda_0000299.jpg
#   inflating: images/Panda_0000300.jpg
#   inflating: images/Panda_0000301.jpg
#   inflating: images/Panda_0000302.jpg
#   inflating: images/Panda_0000303.jpg
#   inflating: images/Panda_0000304.jpg
#   inflating: images/Panda_0000305.jpg
#   inflating: images/Panda_0000306.jpg
#   inflating: images/Panda_0000307.jpg
#   inflating: images/Panda_0000308.jpg
#   inflating: images/Panda_0000309.jpg
#   inflating: images/Panda_0000310.jpg
#   inflating: images/Panda_0000311.jpg
#   inflating: images/Panda_0000313.jpg
#   inflating: images/Panda_0000314.jpg
#   inflating: images/Panda_0000315.jpg
#   inflating: images/Panda_0000316.jpg
#   inflating: images/Panda_0000317.jpg
#   inflating: images/Panda_0000318.jpg
#   inflating: images/Panda_0000319.jpg
#   inflating: images/Panda_0000320.jpg
#   inflating: images/Panda_0000321.jpg
#   inflating: images/Panda_0000322.jpg
#   inflating: images/Panda_0000323.jpg
#   inflating: images/Panda_0000324.jpg
#   inflating: images/Panda_0000325.jpg
#   inflating: images/Panda_0000326.jpg
#   inflating: images/Panda_0000327.jpg
#   inflating: images/Panda_0000328.jpg
#   inflating: images/Panda_0000329.jpg
#   inflating: images/Panda_0000331.jpg
#   inflating: images/Panda_0000332.jpg
#   inflating: images/Panda_0000333.jpg
#   inflating: images/Panda_0000336.jpg
#   inflating: images/Panda_0000337.jpg
#   inflating: images/Panda_0000338.jpg
#   inflating: images/Panda_0000339.jpg
#   inflating: images/Panda_0000342.jpg
#   inflating: images/Panda_0000343.jpg
#   inflating: images/Panda_0000344.jpg
#   inflating: images/Panda_0000345.jpg
#   inflating: images/Panda_0000346.jpg
#   inflating: images/Panda_0000348.jpg
#   inflating: images/Panda_0000349.jpg
#   inflating: images/Panda_0000350.jpg
#   inflating: images/Panda_0000351.jpg
#   inflating: images/Panda_0000352.jpg
#   inflating: images/Panda_0000354.jpg
#   inflating: images/Panda_0000355.jpg
#   inflating: images/Panda_0000356.jpg
#   inflating: images/Panda_0000357.jpg
#   inflating: images/Panda_0000358.jpg
#   inflating: images/Panda_0000359.jpg
#   inflating: images/Panda_0000360.jpg
#   inflating: images/Panda_0000361.jpg
#   inflating: images/Panda_0000362.jpg
#   inflating: images/Panda_0000363.jpg
#   inflating: images/Panda_0000364.jpg
#   inflating: images/Panda_0000365.jpg
#   inflating: images/Panda_0000366.jpg
#   inflating: images/Panda_0000368.jpg
#   inflating: images/Panda_0000369.jpg
#   inflating: images/Panda_0000370.jpg
#   inflating: images/Panda_0000371.jpg
#   inflating: images/Panda_0000373.jpg
#   inflating: images/Panda_0000374.jpg
#   inflating: images/Panda_0000375.jpg
#   inflating: images/Panda_0000378.jpg
#   inflating: images/Panda_0000379.jpg
#   inflating: images/Panda_0000380.jpg
#   inflating: images/Panda_0000381.jpg
#   inflating: images/Panda_0000382.jpg
#   inflating: images/Panda_0000383.jpg
#   inflating: images/Panda_0000384.jpg
#   inflating: images/Panda_0000385.jpg
#   inflating: images/Panda_0000387.jpg
#   inflating: images/Panda_0000388.jpg
#   inflating: images/Panda_0000389.jpg
#   inflating: images/Panda_0000390.jpg
#   inflating: images/Panda_0000391.jpg
#   inflating: images/Panda_0000392.jpg
#   inflating: images/Panda_0000393.jpg
#   inflating: images/Panda_0000394.jpg
#   inflating: images/Panda_0000395.jpg
#   inflating: images/Panda_0000396.jpg
#   inflating: images/Panda_0000398.jpg
#   inflating: images/Panda_0000399.jpg
#   inflating: images/Panda_0000400.jpg
#   inflating: images/Panda_0000401.jpg
#   inflating: images/Panda_0000402.jpg
#   inflating: images/Panda_0000403.jpg
#   inflating: images/Panda_0000404.jpg
#   inflating: images/Panda_0000405.jpg
#   inflating: images/Panda_0000406.jpg
#   inflating: images/Panda_0000407.jpg
#   inflating: images/Panda_0000409.jpg
#   inflating: images/Panda_0000413.jpg
#   inflating: images/Panda_0000414.jpg
#   inflating: images/Panda_0000415.jpg
#   inflating: images/Panda_0000416.jpg
#   inflating: images/Panda_0000417.jpg
#   inflating: images/Panda_0000418.jpg
#   inflating: images/Panda_0000419.jpg
#   inflating: images/Panda_0000421.jpg
#   inflating: images/Panda_0000422.jpg
#   inflating: images/Panda_0000423.jpg
#   inflating: images/Panda_0000424.jpg
#   inflating: images/Panda_0000426.jpg
#   inflating: images/Panda_0000428.jpg
#   inflating: images/Panda_0000429.jpg
#   inflating: images/Panda_0000433.jpg
#   inflating: images/Panda_0000435.jpg
#   inflating: images/Panda_0000437.jpg
#   inflating: images/Panda_0000438.jpg
#   inflating: images/Panda_0000439.jpg
#   inflating: images/Panda_0000440.jpg
#   inflating: images/Panda_0000441.jpg
#   inflating: images/Panda_0000442.jpg
#   inflating: images/Panda_0000443.jpg
#   inflating: images/Panda_0000444.jpg
#   inflating: images/Panda_0000445.jpg
#   inflating: images/Panda_0000446.jpg
#   inflating: images/Panda_0000448.jpg
#   inflating: images/Panda_0000450.jpg
#   inflating: images/Panda_0000451.jpg
#   inflating: images/Panda_0000453.jpg
#   inflating: images/Panda_0000454.jpg
#   inflating: images/Panda_0000455.jpg
#   inflating: images/Panda_0000456.jpg
#   inflating: images/Panda_0000459.jpg
#   inflating: images/Panda_0000461.jpg
#   inflating: images/Panda_0000462.jpg
#   inflating: images/Panda_0000463.jpg
#   inflating: images/Panda_0000464.jpg
#   inflating: images/Panda_0000465.jpg
#   inflating: images/Panda_0000466.jpg
#   inflating: images/Panda_0000467.jpg
#   inflating: images/Panda_0000468.jpg
#   inflating: images/Panda_0000469.jpg
#   inflating: images/Panda_0000470.jpg
#   inflating: images/Panda_0000471.jpg
#   inflating: images/Panda_0000472.jpg
#   inflating: images/Panda_0000473.jpg
#   inflating: images/Panda_0000474.jpg
#   inflating: images/Panda_0000475.jpg
#   inflating: images/Panda_0000477.jpg
#   inflating: images/Panda_0000478.jpg
#   inflating: images/Panda_0000479.jpg
#   inflating: images/Panda_0000480.jpg
#   inflating: images/Panda_0000481.jpg
#   inflating: images/Panda_0000482.jpg
#   inflating: images/Panda_0000483.jpg
#   inflating: images/Panda_0000484.jpg
#   inflating: images/Panda_0000485.jpg
#   inflating: images/Panda_0000486.jpg
#   inflating: images/Panda_0000487.jpg
#   inflating: images/Panda_0000488.jpg
#   inflating: images/Panda_0000490.jpg
#   inflating: images/Panda_0000491.jpg
#   inflating: images/Panda_0000492.jpg
#   inflating: images/Panda_0000493.jpg
#   inflating: images/Panda_0000494.jpg
#   inflating: images/Panda_0000497.jpg
#   inflating: images/Panda_0000498.jpg
#   inflating: images/Panda_0000499.jpg
#   inflating: images/Panda_0000501.jpg
#   inflating: images/Panda_0000502.jpg
#   inflating: images/Panda_0000503.jpg
#   inflating: images/Panda_0000504.jpg
#   inflating: images/Panda_0000505.jpg
#   inflating: images/Panda_0000506.jpg
#   inflating: images/Panda_0000507.jpg
#   inflating: images/Panda_0000508.jpg
#   inflating: images/Panda_0000509.jpg
#   inflating: images/Panda_0000510.jpg
#   inflating: images/Panda_0000512.jpg
#   inflating: images/Panda_0000514.jpg
#   inflating: images/Panda_0000515.jpg
#   inflating: images/Panda_0000516.jpg
#   inflating: images/Panda_0000517.jpg
#   inflating: images/Panda_0000518.jpg
#   inflating: images/Panda_0000519.jpg
#   inflating: images/Panda_0000521.jpg
#   inflating: images/Panda_0000522.jpg
#   inflating: images/Panda_0000523.jpg
#   inflating: images/Panda_0000524.jpg
#   inflating: images/Panda_0000527.jpg
#   inflating: images/Panda_0000528.jpg
#   inflating: images/Panda_0000529.jpg
#   inflating: images/Panda_0000530.jpg
#   inflating: images/Panda_0000533.jpg
#   inflating: images/Panda_0000534.jpg
#   inflating: images/Panda_0000535.jpg
#   inflating: images/Panda_0000536.jpg
#   inflating: images/Panda_0000537.jpg
#   inflating: images/Panda_0000538.jpg
#   inflating: images/Panda_0000539.jpg
#   inflating: images/Panda_0000540.jpg
#   inflating: images/Panda_0000541.jpg
#   inflating: images/Panda_0000542.jpg
#   inflating: images/Panda_0000543.jpg
#   inflating: images/Panda_0000544.jpg
#   inflating: images/Panda_0000545.jpg
#   inflating: images/Panda_0000546.jpg
#   inflating: images/Panda_0000547.jpg
#   inflating: images/Panda_0000549.jpg
#   inflating: images/Panda_0000552.jpg
#   inflating: images/Panda_0000553.jpg
#   inflating: images/Panda_0000554.jpg
#   inflating: images/Panda_0000555.jpg
#   inflating: images/Panda_0000556.jpg
#   inflating: images/Panda_0000557.jpg
#   inflating: images/Panda_0000558.jpg
#   inflating: images/Panda_0000559.jpg
#   inflating: images/Panda_0000561.jpg
#   inflating: images/Panda_0000562.jpg
#   inflating: images/Panda_0000563.jpg
#   inflating: images/Panda_0000564.jpg
#   inflating: images/Panda_0000566.jpg
#   inflating: images/Panda_0000567.jpg
#   inflating: images/Panda_0000568.jpg
#   inflating: images/Panda_0000569.jpg
#   inflating: images/Panda_0000570.jpg
#   inflating: images/Panda_0000571.jpg
#   inflating: images/Panda_0000573.jpg
#   inflating: images/Panda_0000574.jpg
#   inflating: images/Panda_0000575.jpg
#   inflating: images/Panda_0000576.jpg
#   inflating: images/Panda_0000577.jpg
#   inflating: images/Panda_0000578.jpg
#   inflating: images/Panda_0000580.jpg
#   inflating: images/Panda_0000581.jpg
#   inflating: images/Panda_0000582.jpg
#   inflating: images/Panda_0000583.jpg
#   inflating: images/Panda_0000584.jpg
#   inflating: images/Panda_0000585.jpg
#   inflating: images/Panda_0000586.jpg
#   inflating: images/Panda_0000589.jpg
#   inflating: images/Panda_0000590.jpg
#   inflating: images/Panda_0000593.jpg
#   inflating: images/Panda_0000594.jpg
#   inflating: images/Panda_0000595.jpg
#   inflating: images/Panda_0000596.jpg
#   inflating: images/Panda_0000597.jpg
#   inflating: images/Panda_0000598.jpg
#   inflating: images/Panda_0000599.jpg
#   inflating: images/Panda_0000601.jpg
#   inflating: images/Panda_0000602.jpg
#   inflating: images/Panda_0000603.jpg
#   inflating: images/Panda_0000604.jpg
#   inflating: images/Panda_0000605.jpg
#   inflating: images/Panda_0000607.jpg
#   inflating: images/Panda_0000608.jpg
#   inflating: images/Panda_0000609.jpg
#   inflating: images/Panda_0000610.jpg
#   inflating: images/Panda_0000613.jpg
#   inflating: images/Panda_0000614.jpg
#   inflating: images/Panda_0000615.jpg
#   inflating: images/Panda_0000617.jpg
#   inflating: images/Panda_0000618.jpg
#   inflating: images/Panda_0000619.jpg
#   inflating: images/Panda_0000621.jpg
#   inflating: images/Panda_0000622.jpg
#   inflating: images/Panda_0000623.jpg
#   inflating: images/Panda_0000625.jpg
#   inflating: images/Panda_0000626.jpg
#   inflating: images/Panda_0000627.jpg
#   inflating: images/Panda_0000628.jpg
#   inflating: images/Panda_0000630.jpg
#   inflating: images/Panda_0000631.jpg
#   inflating: images/Panda_0000632.jpg
#   inflating: images/Panda_0000633.jpg
#   inflating: images/Panda_0000634.jpg
#   inflating: images/Panda_0000636.jpg
#   inflating: images/Panda_0000637.jpg
#   inflating: images/Panda_0000638.jpg
#   inflating: images/Panda_0000639.jpg
#   inflating: images/Panda_0000641.jpg
#   inflating: images/Panda_0000642.jpg
#   inflating: images/Panda_0000643.jpg
#   inflating: images/Panda_0000644.jpg
#   inflating: images/Panda_0000645.jpg
#   inflating: images/Panda_0000646.jpg
#   inflating: images/Panda_0000649.jpg
#   inflating: images/Panda_0000651.jpg
#   inflating: images/Panda_0000652.jpg
#   inflating: images/Panda_0000654.jpg
#   inflating: images/Panda_0000655.jpg
#   inflating: images/Panda_0000656.jpg
#   inflating: images/Panda_0000657.jpg
#   inflating: images/Panda_0000658.jpg
#   inflating: images/Panda_0000659.jpg
#   inflating: images/Panda_0000661.jpg
#   inflating: images/Panda_0000662.jpg
#   inflating: images/Panda_0000665.jpg
#   inflating: images/Panda_0000666.jpg
#   inflating: images/Panda_0000667.jpg
#   inflating: images/Panda_0000668.jpg
#   inflating: images/Panda_0000669.jpg
#   inflating: images/Panda_0000670.jpg
#   inflating: images/Panda_0000671.jpg
#   inflating: images/Panda_0000673.jpg
#   inflating: images/Panda_0000677.jpg
#   inflating: images/Panda_0000678.jpg
#   inflating: images/Panda_0000679.jpg
#   inflating: images/Panda_0000680.jpg
#   inflating: images/Panda_0000681.jpg
#   inflating: images/Panda_0000682.jpg
#   inflating: images/Panda_0000683.jpg
#   inflating: images/Panda_0000684.jpg
#   inflating: images/Panda_0000685.jpg
#   inflating: images/Panda_0000686.jpg
#   inflating: images/Panda_0000687.jpg
#   inflating: images/Panda_0000688.jpg
#   inflating: images/Panda_0000689.jpg
#   inflating: images/Panda_0000690.jpg
#   inflating: images/Panda_0000692.jpg
#   inflating: images/Panda_0000694.jpg
#   inflating: images/Panda_0000695.jpg
#   inflating: images/Panda_0000696.jpg
#   inflating: images/Panda_0000697.jpg
#   inflating: images/Panda_0000699.jpg
#   inflating: images/Panda_0000700.jpg
#   inflating: images/Panda_0000701.jpg
#   inflating: images/Panda_0000702.jpg
#   inflating: images/Panda_0000703.jpg
#   inflating: images/Panda_0000704.jpg
#   inflating: images/Panda_0000705.jpg
#   inflating: images/Panda_0000706.jpg
#   inflating: images/Panda_0000707.jpg
#   inflating: images/Panda_0000709.jpg
#   inflating: images/Panda_0000711.jpg
#   inflating: images/Panda_0000712.jpg
#   inflating: images/Panda_0000714.jpg
#   inflating: images/Panda_0000716.jpg
#   inflating: images/Panda_0000718.jpg
#   inflating: images/Panda_0000719.jpg
#   inflating: images/Panda_0000720.jpg
#   inflating: images/Panda_0000721.jpg
#   inflating: images/Panda_0000722.jpg
#   inflating: images/Panda_0000723.jpg
#   inflating: images/Panda_0000724.jpg
#   inflating: images/Panda_0000727.jpg
#   inflating: images/Panda_0000728.jpg
#   inflating: images/Panda_0000729.jpg
#   inflating: images/Panda_0000730.jpg
#   inflating: images/Panda_0000731.jpg
#   inflating: images/Panda_0000732.jpg
#   inflating: images/Panda_0000734.jpg
#   inflating: images/Panda_0000735.jpg
#   inflating: images/Panda_0000736.jpg
#   inflating: images/Panda_0000738.jpg
#   inflating: images/Panda_0000739.jpg
#   inflating: images/Panda_0000740.jpg
#   inflating: images/Panda_0000741.jpg
#   inflating: images/Panda_0000742.jpg
#   inflating: images/Panda_0000743.jpg
#   inflating: images/Panda_0000744.jpg
#   inflating: images/Panda_0000745.jpg
#   inflating: images/Panda_0000746.jpg
#   inflating: images/Panda_0000747.jpg
#   inflating: images/Panda_0000752.jpg
#   inflating: images/Panda_0000753.jpg
#   inflating: images/Panda_0000754.jpg
#   inflating: images/Panda_0000756.jpg
#   inflating: images/Panda_0000759.jpg
#   inflating: images/Panda_0000760.jpg
#   inflating: images/Panda_0000763.jpg
#   inflating: images/Panda_0000764.jpg
#   inflating: images/Panda_0000765.jpg
#   inflating: images/Panda_0000767.jpg
#   inflating: images/Panda_0000769.jpg
#   inflating: images/Panda_0000770.jpg
#   inflating: images/Panda_0000771.jpg
#   inflating: images/Panda_0000773.jpg
#   inflating: images/Panda_0000774.jpg
#   inflating: images/Panda_0000775.jpg
#   inflating: images/Panda_0000776.jpg
#   inflating: images/Panda_0000779.jpg
#   inflating: images/Panda_0000780.jpg
#   inflating: images/Panda_0000781.jpg
#   inflating: images/Panda_0000782.jpg
#   inflating: images/Panda_0000783.jpg
#   inflating: images/Panda_0000784.jpg
#   inflating: images/Panda_0000786.jpg
#   inflating: images/Panda_0000788.jpg
#   inflating: images/Panda_0000789.jpg
#   inflating: images/Panda_0000791.jpg
#   inflating: images/Panda_0000792.jpg
#   inflating: images/Panda_0000794.jpg
#   inflating: images/Panda_0000796.jpg
#   inflating: images/Panda_0000798.jpg
#   inflating: images/Panda_0000800.jpg
#   inflating: images/Panda_0000802.jpg
#   inflating: images/Panda_0000803.jpg
#   inflating: images/Panda_0000804.jpg
#   inflating: images/Panda_0000805.jpg
#   inflating: images/Panda_0000806.jpg
#   inflating: images/Panda_0000808.jpg
#   inflating: images/Panda_0000810.jpg
#   inflating: images/Panda_0000811.jpg
#   inflating: images/Panda_0000812.jpg
#   inflating: images/Panda_0000813.jpg
#   inflating: images/Panda_0000814.jpg
#   inflating: images/Panda_0000815.jpg
#   inflating: images/Panda_0000817.jpg
#   inflating: images/Panda_0000818.jpg
#   inflating: images/Panda_0000819.jpg
#   inflating: images/Panda_0000820.jpg
#   inflating: images/Panda_0000821.jpg
#   inflating: images/Panda_0000824.jpg
#   inflating: images/Panda_0000825.jpg
#   inflating: images/Panda_0000826.jpg
#   inflating: images/Panda_0000827.jpg
#   inflating: images/Panda_0000828.jpg
#   inflating: images/Panda_0000829.jpg
#   inflating: images/Panda_0000830.jpg
#   inflating: images/Panda_0000831.jpg
#   inflating: images/Panda_0000832.jpg
#   inflating: images/Panda_0000833.jpg
#   inflating: images/Panda_0000835.jpg
#   inflating: images/Panda_0000837.jpg
#   inflating: images/Panda_0000839.jpg
#   inflating: images/Panda_0000840.jpg
#   inflating: images/Panda_0000841.jpg
#   inflating: images/Panda_0000845.jpg
#   inflating: images/Panda_0000848.jpg
#   inflating: images/Panda_0000849.jpg
#   inflating: images/Panda_0000851.jpg
#   inflating: images/Panda_0000853.jpg
#   inflating: images/Panda_0000854.jpg
#   inflating: images/Panda_0000857.jpg
#   inflating: images/Panda_0000859.jpg
#   inflating: images/Panda_0000860.jpg
#   inflating: images/Panda_0000862.jpg
#   inflating: images/Panda_0000865.jpg
#   inflating: images/Panda_0000866.jpg
#   inflating: images/Panda_0000867.jpg
#   inflating: images/Panda_0000868.jpg
#   inflating: images/Panda_0000869.jpg
#   inflating: images/Panda_0000870.jpg
#   inflating: images/Panda_0000873.jpg
#   inflating: images/Panda_0000874.jpg
#   inflating: images/Panda_0000875.jpg
#   inflating: images/Panda_0000876.jpg
#   inflating: images/Panda_0000878.jpg
#   inflating: images/Panda_0000879.jpg
#   inflating: images/Panda_0000880.jpg
#   inflating: images/Panda_0000882.jpg
#   inflating: images/Panda_0000883.jpg
#   inflating: images/Panda_0000885.jpg
#   inflating: images/Panda_0000887.jpg
#   inflating: images/Panda_0000888.jpg
#   inflating: images/Panda_0000889.jpg
#   inflating: images/Panda_0000890.jpg
#   inflating: images/Panda_0000891.jpg
#   inflating: images/Panda_0000893.jpg
#   inflating: images/Panda_0000894.jpg
#   inflating: images/Panda_0000896.jpg
#   inflating: images/Panda_0000897.jpg
#   inflating: images/Panda_0000898.jpg
#   inflating: images/Panda_0000899.jpg
#   inflating: images/Panda_0000902.jpg
#   inflating: images/Panda_0000907.jpg
#   inflating: images/Panda_0000908.jpg
#   inflating: images/Panda_0000909.jpg
#   inflating: images/Panda_0000910.jpg
#   inflating: images/Panda_0000911.jpg
#   inflating: images/Panda_0000912.jpg
#   inflating: images/Panda_0000913.jpg
#   inflating: images/Panda_0000914.jpg
#   inflating: images/Panda_0000915.jpg
#   inflating: images/Panda_0000916.jpg
#   inflating: images/Panda_0000918.jpg
#   inflating: images/Panda_0000919.jpg
#   inflating: images/Panda_0000922.jpg
#   inflating: images/Panda_0000923.jpg
#   inflating: images/Panda_0000924.jpg
#   inflating: images/Panda_0000925.jpg
#   inflating: images/Panda_0000929.jpg
#   inflating: images/Panda_0000931.jpg
#   inflating: images/Panda_0000933.jpg
#   inflating: images/Panda_0000934.jpg
#   inflating: images/Panda_0000935.jpg
#   inflating: images/Panda_0000936.jpg
#   inflating: images/Panda_0000938.jpg
#   inflating: images/Panda_0000939.jpg
#   inflating: images/Panda_0000941.jpg
#   inflating: images/Panda_0000942.jpg
#   inflating: images/Panda_0000943.jpg
#   inflating: images/Panda_0000945.jpg
#   inflating: images/Panda_0000946.jpg
#   inflating: images/Panda_0000948.jpg
#   inflating: images/Panda_0000949.jpg
#   inflating: images/Panda_0000950.jpg
#   inflating: images/Panda_0000951.jpg
#   inflating: images/Panda_0000952.jpg
#   inflating: images/Panda_0000953.jpg
#   inflating: images/Panda_0000954.jpg
#   inflating: images/Panda_0000955.jpg
#   inflating: images/Panda_0000956.jpg
#   inflating: images/Panda_0000958.jpg
#   inflating: images/Panda_0000959.jpg
#   inflating: images/Panda_0000960.jpg
#   inflating: images/Panda_0000961.jpg
#   inflating: images/Panda_0000962.jpg
#   inflating: images/Panda_0000963.jpg
#   inflating: images/Panda_0000964.jpg
#   inflating: images/Panda_0000965.jpg
#   inflating: images/Panda_0000967.jpg
#   inflating: images/Panda_0000970.jpg
#   inflating: images/Panda_0000971.jpg
#   inflating: images/Panda_0000972.jpg
#   inflating: images/Panda_0000975.jpg
#   inflating: images/Panda_0000978.jpg
#   inflating: images/Panda_0000981.jpg
#   inflating: images/Panda_0000983.jpg
#   inflating: images/Panda_0000984.jpg
#   inflating: images/Panda_0000985.jpg
#   inflating: images/Panda_0000988.jpg
#   inflating: images/Panda_0000993.jpg
#   inflating: images/Panda_0000995.jpg
#   inflating: images/Panda_0000996.jpg
#   inflating: images/Panda_0000997.jpg
#   inflating: images/Panda_0000999.jpg
#   inflating: images/Panda_0001002.jpg
#   inflating: images/Panda_0001003.jpg
#   inflating: images/Panda_0001004.jpg
#   inflating: images/Panda_0001005.jpg
#   inflating: images/Panda_0001006.jpg
#   inflating: images/Panda_0001008.jpg
#   inflating: images/Panda_0001009.jpg
#   inflating: images/Panda_0001011.jpg
#   inflating: images/Panda_0001012.jpg
#   inflating: images/Panda_0001013.jpg
#   inflating: images/Panda_0001014.jpg
#   inflating: images/Panda_0001015.jpg
#   inflating: images/Panda_0001016.jpg
#   inflating: images/Panda_0001017.jpg
#   inflating: images/Panda_0001019.jpg
#   inflating: images/Panda_0001021.jpg
#   inflating: images/Panda_0001022.jpg
#   inflating: images/Panda_0001023.jpg
#   inflating: images/Panda_0001024.jpg
#   inflating: images/Panda_0001026.jpg
#   inflating: images/Panda_0001027.jpg
#   inflating: images/Panda_0001030.jpg
#   inflating: images/Panda_0001031.jpg
#   inflating: images/Panda_0001033.jpg
#   inflating: images/Panda_0001034.jpg
#   inflating: images/Panda_0001036.jpg
#   inflating: images/Panda_0001037.jpg
#   inflating: images/Panda_0001039.jpg
#   inflating: images/Panda_0001040.jpg
#   inflating: images/Panda_0001044.jpg
#   inflating: images/Panda_0001046.jpg
#   inflating: images/Panda_0001047.jpg
#   inflating: images/Panda_0001049.jpg
#   inflating: images/Panda_0001050.jpg
#   inflating: images/Panda_0001051.jpg
#   inflating: images/Panda_0001052.jpg
#   inflating: images/Panda_0001053.jpg
#   inflating: images/Panda_0001055.jpg
#   inflating: images/Panda_0001058.jpg
#   inflating: images/Panda_0001059.jpg
#   inflating: images/Panda_0001061.jpg
#   inflating: images/Panda_0001062.jpg
#   inflating: images/Panda_0001063.jpg
#   inflating: images/Panda_0001064.jpg
#   inflating: images/Panda_0001067.jpg
#   inflating: images/Panda_0001069.jpg
#   inflating: images/Panda_0001070.jpg
#   inflating: images/Panda_0001073.jpg
#   inflating: images/Panda_0001074.jpg
#   inflating: images/Panda_0001075.jpg
#   inflating: images/Panda_0001076.jpg
#   inflating: images/Panda_0001077.jpg
#   inflating: images/Panda_0001078.jpg
#   inflating: images/Panda_0001079.jpg
#   inflating: images/Panda_0001080.jpg
#   inflating: images/Panda_0001083.jpg
#   inflating: images/Panda_0001085.jpg
#   inflating: images/Panda_0001089.jpg
#   inflating: images/Panda_0001091.jpg
#   inflating: images/Panda_0001096.jpg
#   inflating: images/Panda_0001097.jpg
#   inflating: images/Panda_0001098.jpg
#   inflating: images/Panda_0001104.jpg
#   inflating: images/Panda_0001107.jpg
#   inflating: images/Panda_0001108.jpg
#   inflating: images/Panda_0001109.jpg
#   inflating: images/Panda_0001110.jpg
#   inflating: images/Panda_0001111.jpg
#   inflating: images/Panda_0001112.jpg
#   inflating: images/Panda_0001114.jpg
#   inflating: images/Panda_0001117.jpg
#   inflating: images/Panda_0001120.jpg
#   inflating: images/Panda_0001121.jpg
#   inflating: images/Panda_0001122.jpg
#   inflating: images/Panda_0001123.jpg
#   inflating: images/Panda_0001126.jpg
#   inflating: images/Panda_0001127.jpg
#   inflating: images/Panda_0001128.jpg
#   inflating: images/Panda_0001130.jpg
#   inflating: images/Panda_0001131.jpg
#   inflating: images/Panda_0001132.jpg
#   inflating: images/Panda_0001134.jpg
#   inflating: images/Panda_0001135.jpg
#   inflating: images/Panda_0001137.jpg
#   inflating: images/Panda_0001138.jpg
#   inflating: images/Panda_0001139.jpg
#   inflating: images/Panda_0001140.jpg
#   inflating: images/Panda_0001141.jpg
#   inflating: images/Panda_0001142.jpg
#   inflating: images/Panda_0001146.jpg
#   inflating: images/Panda_0001147.jpg
#   inflating: images/Panda_0001148.jpg
#   inflating: images/Panda_0001149.jpg
#   inflating: images/Panda_0001150.jpg
#   inflating: images/Panda_0001151.jpg
#   inflating: images/Panda_0001153.jpg
#   inflating: images/Panda_0001154.jpg
#   inflating: images/Panda_0001155.jpg
#   inflating: images/Panda_0001156.jpg
#   inflating: images/Panda_0001158.jpg
#   inflating: images/Panda_0001159.jpg
#   inflating: images/Panda_0001160.jpg
#   inflating: images/Panda_0001161.jpg
#   inflating: images/Panda_0001162.jpg
#   inflating: images/Panda_0001163.jpg
#   inflating: images/Panda_0001164.jpg
#   inflating: images/Panda_0001166.jpg
#   inflating: images/Panda_0001169.jpg
#   inflating: images/Panda_0001170.jpg
#   inflating: images/Panda_0001171.jpg
#   inflating: images/Panda_0001172.jpg
#   inflating: images/Panda_0001173.jpg
#   inflating: images/Panda_0001174.jpg
#   inflating: images/Panda_0001176.jpg
#   inflating: images/Panda_0001180.jpg
#   inflating: images/Panda_0001181.jpg
#   inflating: images/Panda_0001185.jpg
#   inflating: images/Panda_0001186.jpg
#   inflating: images/Panda_0001187.jpg
#   inflating: images/Panda_0001188.jpg
#   inflating: images/Panda_0001190.jpg
#   inflating: images/Panda_0001191.jpg
#   inflating: images/Panda_0001192.jpg
#   inflating: images/Panda_0001193.jpg
#   inflating: images/Panda_0001196.jpg
#   inflating: images/Panda_0001197.jpg
#   inflating: images/Panda_0001200.jpg
#   inflating: images/Panda_0001203.jpg
#   inflating: images/Panda_0001205.jpg
#   inflating: images/Panda_0001206.jpg
#   inflating: images/Panda_0001207.jpg
#   inflating: images/Panda_0001210.jpg
#   inflating: images/Panda_0001211.jpg
#   inflating: images/Panda_0001212.jpg
#   inflating: images/Panda_0001219.jpg
#   inflating: images/Panda_0001220.jpg
#   inflating: images/Panda_0001222.jpg
#   inflating: images/Panda_0001223.jpg
#   inflating: images/Panda_0001224.jpg
#   inflating: images/Panda_0001227.jpg
#   inflating: images/Panda_0001228.jpg
#   inflating: images/Panda_0001229.jpg
#   inflating: images/Panda_0001231.jpg
#   inflating: images/Panda_0001232.jpg
#   inflating: images/Panda_0001233.jpg
#   inflating: images/Panda_0001234.jpg
#   inflating: images/Panda_0001236.jpg
#   inflating: images/Panda_0001237.jpg
#   inflating: images/Panda_0001238.jpg
#   inflating: images/Panda_0001241.jpg
#   inflating: images/Panda_0001243.jpg
#   inflating: images/Panda_0001245.jpg
#   inflating: images/Panda_0001246.jpg
#   inflating: images/Panda_0001247.jpg
#   inflating: images/Panda_0001248.jpg
#   inflating: images/Panda_0001249.jpg
#   inflating: images/Panda_0001251.jpg
#   inflating: images/Panda_0001252.jpg
#   inflating: images/Panda_0001255.jpg
#   inflating: images/Panda_0001259.jpg
#   inflating: images/Panda_0001260.jpg
#   inflating: images/Panda_0001265.jpg
#   inflating: images/Panda_0001269.jpg
#   inflating: images/Panda_0001272.jpg
#   inflating: images/Panda_0001273.jpg
#   inflating: images/Panda_0001275.jpg
#   inflating: images/Panda_0001277.jpg
#   inflating: images/Panda_0001278.jpg
#   inflating: images/Panda_0001280.jpg
#   inflating: images/Panda_0001281.jpg
#   inflating: images/Panda_0001282.jpg
#   inflating: images/Panda_0001283.jpg
#   inflating: images/Panda_0001285.jpg
#   inflating: images/Panda_0001286.jpg
#   inflating: images/Panda_0001287.jpg
#   inflating: images/Panda_0001288.jpg
#   inflating: images/Panda_0001291.jpg
#   inflating: images/Panda_0001292.jpg
#   inflating: images/Panda_0001293.jpg
#   inflating: images/Panda_0001294.jpg
#   inflating: images/Panda_0001295.jpg
#   inflating: images/Panda_0001297.jpg
#   inflating: images/Panda_0001300.jpg
#   inflating: images/Panda_0001303.jpg
#   inflating: images/Panda_0001304.jpg
#   inflating: images/Panda_0001306.jpg
#   inflating: images/Panda_0001309.jpg
#   inflating: images/Panda_0001311.jpg
#   inflating: images/Panda_0001312.jpg
#   inflating: images/Panda_0001313.jpg
#   inflating: images/Panda_0001315.jpg
#   inflating: images/Panda_0001316.jpg
#   inflating: images/Panda_0001317.jpg
#   inflating: images/Panda_0001319.jpg
#   inflating: images/Panda_0001321.jpg
#   inflating: images/Panda_0001324.jpg
#   inflating: images/Panda_0001325.jpg
#   inflating: images/Panda_0001327.jpg
#   inflating: images/Panda_0001328.jpg
#   inflating: images/Panda_0001329.jpg
#   inflating: images/Panda_0001333.jpg
#   inflating: images/Panda_0001337.jpg
#   inflating: images/Panda_0001338.jpg
#   inflating: images/Panda_0001340.jpg
#   inflating: images/Panda_0001342.jpg
#   inflating: images/Panda_0001346.jpg
#   inflating: images/Panda_0001348.jpg
#   inflating: images/Panda_0001349.jpg
#   inflating: images/Panda_0001352.jpg
#   inflating: images/Panda_0001353.jpg
#   inflating: images/Panda_0001355.jpg
#   inflating: images/Panda_0001356.jpg
#   inflating: images/Panda_0001359.jpg
#   inflating: images/Panda_0001360.jpg
#   inflating: images/Panda_0001361.jpg
#   inflating: images/Panda_0001362.jpg
#   inflating: images/Panda_0001363.jpg
#   inflating: images/Panda_0001364.jpg
#   inflating: images/Panda_0001365.jpg
#   inflating: images/Panda_0001366.jpg
#   inflating: images/Panda_0001367.jpg
#   inflating: images/Panda_0001368.jpg
#   inflating: images/Panda_0001369.jpg
#   inflating: images/Panda_0001370.jpg
#   inflating: images/Panda_0001372.jpg
#   inflating: images/Panda_0001375.jpg
#   inflating: images/Panda_0001376.jpg
#   inflating: images/Panda_0001378.jpg
#   inflating: images/Panda_0001379.jpg
#   inflating: images/Panda_0001380.jpg
#   inflating: images/Panda_0001381.jpg
#   inflating: images/Panda_0001382.jpg
#   inflating: images/Panda_0001384.jpg
#   inflating: images/Panda_0001386.jpg
#   inflating: images/Panda_0001387.jpg
#   inflating: images/Panda_0001388.jpg
#   inflating: images/Panda_0001391.jpg
#   inflating: images/Panda_0001392.jpg
#   inflating: images/Panda_0001394.jpg
#   inflating: images/Panda_0001395.jpg
#   inflating: images/Panda_0001396.jpg
#   inflating: images/Panda_0001397.jpg
#   inflating: images/Panda_0001398.jpg
#   inflating: images/Panda_0001399.jpg
#   inflating: images/Panda_0001400.jpg
#   inflating: images/Panda_0001404.jpg
#   inflating: images/Panda_0001405.jpg
#   inflating: images/Panda_0001407.jpg
#   inflating: images/Panda_0001409.jpg
#   inflating: images/Panda_0001411.jpg
#   inflating: images/Panda_0001414.jpg
#   inflating: images/Panda_0001415.jpg
#   inflating: images/Panda_0001416.jpg
#   inflating: images/Panda_0001417.jpg
#   inflating: images/Panda_0001419.jpg
#   inflating: images/Panda_0001424.jpg
#   inflating: images/Panda_0001425.jpg
#   inflating: images/Panda_0001430.jpg
#   inflating: images/Panda_0001431.jpg
#   inflating: images/Panda_0001433.jpg
#   inflating: images/Panda_0001435.jpg
#   inflating: images/Panda_0001436.jpg
#   inflating: images/Panda_0001437.jpg
#   inflating: images/Panda_0001438.jpg
#   inflating: images/Panda_0001439.jpg
#   inflating: images/Panda_0001441.jpg
#   inflating: images/Panda_0001449.jpg
#   inflating: images/Panda_0001450.jpg
#   inflating: images/Panda_0001452.jpg
#   inflating: images/Panda_0001454.jpg
#   inflating: images/Panda_0001455.jpg
#   inflating: images/Panda_0001458.jpg
#   inflating: images/Panda_0001463.jpg
#   inflating: images/Panda_0001465.jpg
#   inflating: images/Panda_0001466.jpg
#   inflating: images/Panda_0001471.jpg
#   inflating: images/Panda_0001474.jpg
#   inflating: images/Panda_0001475.jpg
#   inflating: images/Panda_0001478.jpg
#   inflating: images/Panda_0001479.jpg
#   inflating: images/Panda_0001481.jpg
#   inflating: images/Panda_0001484.jpg
#   inflating: images/Panda_0001486.jpg
#   inflating: images/Panda_0001487.jpg
#   inflating: images/Panda_0001488.jpg
#   inflating: images/Panda_0001489.jpg
#   inflating: images/Panda_0001494.jpg
#   inflating: images/Panda_0001496.jpg
#   inflating: images/Panda_0001497.jpg
#   inflating: images/Panda_0001498.jpg
#   inflating: images/Panda_0001499.jpg
#   inflating: images/Panda_0001501.jpg
#   inflating: images/Panda_0001502.jpg
#   inflating: images/Panda_0001503.jpg
#   inflating: images/Panda_0001505.jpg
#   inflating: images/Panda_0001507.jpg
#   inflating: images/Panda_0001509.jpg
#   inflating: images/Panda_0001510.jpg
#   inflating: images/Panda_0001513.jpg
#   inflating: images/Panda_0001515.jpg
#   inflating: images/Panda_0001517.jpg
#   inflating: images/Panda_0001519.jpg
#   inflating: images/Panda_0001521.jpg
#   inflating: images/Panda_0001523.jpg
#   inflating: images/Panda_0001525.jpg
#   inflating: images/Panda_0001526.jpg
#   inflating: images/Panda_0001529.jpg
#   inflating: images/Panda_0001533.jpg
#   inflating: images/Panda_0001537.jpg
#   inflating: images/Panda_0001540.jpg
#   inflating: images/Panda_0001542.jpg
#   inflating: images/Panda_0001543.jpg
#   inflating: images/Panda_0001544.jpg
#   inflating: images/Panda_0001546.jpg
#   inflating: images/Panda_0001550.jpg
#   inflating: images/Panda_0001551.jpg
#   inflating: images/Panda_0001554.jpg
#   inflating: images/Panda_0001557.jpg
#   inflating: images/Panda_0001558.jpg
#   inflating: images/Panda_0001559.jpg
#   inflating: images/Panda_0001560.jpg
#   inflating: images/Panda_0001561.jpg
#   inflating: images/Panda_0001562.jpg
#   inflating: images/Panda_0001563.jpg
#   inflating: images/Panda_0001566.jpg
#   inflating: images/Panda_0001567.jpg
#   inflating: images/Panda_0001571.jpg
#   inflating: images/Panda_0001572.jpg
#   inflating: images/Panda_0001579.jpg
#   inflating: images/Panda_0001582.jpg
#   inflating: images/Panda_0001584.jpg
#   inflating: images/Panda_0001590.jpg
#   inflating: images/Panda_0001591.jpg
#   inflating: images/Panda_0001592.jpg
#   inflating: images/Panda_0001594.jpg
#   inflating: images/Panda_0001598.jpg
#   inflating: images/Panda_0001602.jpg
#   inflating: images/Panda_0001603.jpg
#   inflating: images/Panda_0001604.jpg
#   inflating: images/Panda_0001606.jpg
#   inflating: images/Panda_0001607.jpg
#   inflating: images/Panda_0001609.jpg
#   inflating: images/Panda_0001612.jpg
#   inflating: images/Panda_0001613.jpg
#   inflating: images/Panda_0001615.jpg
#   inflating: images/Panda_0001617.jpg
#   inflating: images/Panda_0001619.jpg
#   inflating: images/Panda_0001622.jpg
#   inflating: images/Panda_0001628.jpg
#   inflating: images/Panda_0001629.jpg
#   inflating: images/Panda_0001630.jpg
#   inflating: images/Panda_0001633.jpg
#   inflating: images/Panda_0001634.jpg
#   inflating: images/Panda_0001635.jpg
#   inflating: images/Panda_0001636.jpg
#   inflating: images/Panda_0001638.jpg
#   inflating: images/Panda_0001640.jpg
#   inflating: images/Panda_0001641.jpg
#   inflating: images/Panda_0001642.jpg
#   inflating: images/Panda_0001643.jpg
#   inflating: images/Panda_0001645.jpg
#   inflating: images/Panda_0001647.jpg
#   inflating: images/Panda_0001648.jpg
#   inflating: images/Panda_0001649.jpg
#   inflating: images/Panda_0001651.jpg
#   inflating: images/Panda_0001652.jpg
#   inflating: images/Panda_0001653.jpg
#   inflating: images/Panda_0001654.jpg
#   inflating: images/Panda_0001657.jpg
#   inflating: images/Panda_0001658.jpg
#   inflating: images/Panda_0001659.jpg
#   inflating: images/Panda_0001660.jpg
#   inflating: images/Panda_0001661.jpg
#   inflating: images/Panda_0001662.jpg
#   inflating: images/Panda_0001664.jpg
#   inflating: images/Panda_0001665.jpg
#   inflating: images/Panda_0001671.jpg
#   inflating: images/Panda_0001672.jpg
#   inflating: images/Panda_0001676.jpg
#   inflating: images/Panda_0001687.jpg
#   inflating: images/Panda_0001688.jpg
#   inflating: images/Panda_0001690.jpg
#   inflating: images/Panda_0001691.jpg
#   inflating: images/Panda_0001692.jpg
#   inflating: images/Panda_0001693.jpg
#   inflating: images/Panda_0001694.jpg
#   inflating: images/Panda_0001697.jpg
#   inflating: images/Panda_0001698.jpg
#   inflating: images/Panda_0001708.jpg
#   inflating: images/Panda_0001711.jpg
#   inflating: images/Panda_0001713.jpg
#   inflating: images/Panda_0001715.jpg
#   inflating: images/Panda_0001716.jpg
#   inflating: images/Panda_0001718.jpg
#   inflating: images/Panda_0001719.jpg
#   inflating: images/Panda_0001721.jpg
#   inflating: images/Panda_0001722.jpg
#   inflating: images/Panda_0001723.jpg
#   inflating: images/Panda_0001724.jpg
# ...
#   inflating: images/Panda_0017541.jpg
#   inflating: images/Panda_0017550.jpg
#   inflating: images/Panda_0017566.jpg
#   inflating: images/Panda_0017571.jpg
#   inflating: images/Panda_0017577.jpg
#   inflating: images/Panda_0017583.jpg
#   inflating: images/Panda_0017591.jpg
#   inflating: images/Panda_0017599.jpg
#   inflating: images/Panda_0017604.jpg
#   inflating: images/Panda_0017623.jpg
#   inflating: images/Panda_0017633.jpg
#   inflating: images/Panda_0017634.jpg
#   inflating: images/Panda_0017637.jpg
#   inflating: images/Panda_0017641.jpg
#   inflating: images/Panda_0017658.jpg
#   inflating: images/Panda_0017660.jpg
#   inflating: images/Panda_0017675.jpg
#   inflating: images/Panda_0017730.jpg
#   inflating: images/Panda_0017747.jpg
#   inflating: images/Panda_0017768.jpg
#   inflating: images/Panda_0017795.jpg
#   inflating: images/Panda_0017798.jpg
#   inflating: images/Panda_0017800.jpg
#   inflating: images/Panda_0017813.jpg
#   inflating: images/Panda_0017814.jpg
#   inflating: images/Panda_0017817.jpg
#   inflating: images/Panda_0017834.jpg
#   inflating: images/Panda_0017855.jpg
#   inflating: images/Panda_0017856.jpg
#   inflating: images/Panda_0017864.jpg
#   inflating: images/Panda_0017865.jpg
#   inflating: images/Panda_0017870.jpg
#   inflating: images/Panda_0017874.jpg
#   inflating: images/Panda_0017875.jpg
#   inflating: images/Panda_0017883.jpg
#   inflating: images/Panda_0017895.jpg
#   inflating: images/Panda_0017900.jpg
#   inflating: images/Panda_0017902.jpg
#   inflating: images/Panda_0017903.jpg
#   inflating: images/Panda_0017907.jpg
#   inflating: images/Panda_0017913.jpg
#   inflating: images/Panda_0017925.jpg
#   inflating: images/Panda_0017926.jpg
#   inflating: images/Panda_0017927.jpg
#   inflating: images/Panda_0017928.jpg
#   inflating: images/Panda_0017929.jpg
#   inflating: images/Panda_0017930.jpg
#   inflating: images/Panda_0017931.jpg
#   inflating: images/Panda_0017932.jpg
#   inflating: images/Panda_0017933.jpg
#   inflating: images/Panda_0017934.jpg
#   inflating: images/Panda_0017935.jpg
#   inflating: images/Panda_0017936.jpg
#   inflating: images/Panda_0017937.jpg
#   inflating: images/Panda_0017940.jpg
#   inflating: images/Panda_0017942.jpg
#   inflating: images/Panda_0017947.jpg
#   inflating: images/Panda_0017976.jpg
#   inflating: images/Panda_0017977.jpg
#   inflating: images/Panda_0017978.jpg
#   inflating: images/Panda_0017979.jpg
#   inflating: images/Panda_0017980.jpg
#   inflating: images/Panda_0017981.jpg
#   inflating: images/Panda_0017982.jpg
#   inflating: images/Panda_0017983.jpg
#   inflating: images/Panda_0017989.jpg
#   inflating: images/Panda_0018010.jpg
#   inflating: images/Panda_0018011.jpg
#   inflating: images/Panda_0018012.jpg
#   inflating: images/Panda_0018020.jpg
#   inflating: images/Panda_0018021.jpg
#   inflating: images/Panda_0018022.jpg
#   inflating: images/Panda_0018023.jpg
#   inflating: images/Panda_0018024.jpg
#   inflating: images/Panda_0018025.jpg
#   inflating: images/Panda_0018026.jpg
#   inflating: images/Panda_0018027.jpg
#   inflating: images/Panda_0018028.jpg
#   inflating: images/Panda_0018030.jpg
#   inflating: images/Panda_0018040.jpg
#   inflating: images/Panda_0018112.jpg
#   inflating: images/Panda_0018116.jpg
#   inflating: images/Panda_0018126.jpg
#   inflating: images/Panda_0018128.jpg
#   inflating: images/Panda_0018137.jpg
#   inflating: images/Panda_0018138.jpg
#   inflating: images/Panda_0018140.jpg
#   inflating: images/Panda_0018147.jpg
#   inflating: images/Panda_0018168.jpg
#   inflating: images/Panda_0018171.jpg
#   inflating: images/Panda_0018172.jpg
#   inflating: images/Panda_0018187.jpg
#   inflating: images/Panda_0018193.jpg
#   inflating: images/Panda_0018202.jpg
#   inflating: images/Panda_0018203.jpg
#   inflating: images/Panda_0018206.jpg
#   inflating: images/Panda_0018207.jpg
#   inflating: images/Panda_0018208.jpg
#   inflating: images/Panda_0018209.jpg
#   inflating: images/Panda_0018226.jpg
#   inflating: images/Panda_0018227.jpg
#   inflating: images/Panda_0018228.jpg
#   inflating: images/Panda_0018230.jpg
#   inflating: images/Panda_0018231.jpg
#   inflating: images/Panda_0018232.jpg
#   inflating: images/Panda_0018233.jpg
#   inflating: images/Panda_0018235.jpg
#   inflating: images/Panda_0018236.jpg
#   inflating: images/Panda_0018237.jpg
#   inflating: images/Panda_0018238.jpg
#   inflating: images/Panda_0018240.jpg
#   inflating: images/Panda_0018241.jpg
#   inflating: images/Panda_0018243.jpg
#   inflating: images/Panda_0018245.jpg
#   inflating: images/Panda_0018248.jpg
#   inflating: images/Panda_0018252.jpg
#   inflating: images/Panda_0018256.jpg
#   inflating: images/Panda_0018284.jpg
#   inflating: images/Panda_0018286.jpg
#   inflating: images/Panda_0018287.jpg
#   inflating: images/Panda_0018288.jpg
#   inflating: images/Panda_0018289.jpg
#   inflating: images/Panda_0018290.jpg
#   inflating: images/Panda_0018291.jpg
#   inflating: images/Panda_0018292.jpg
#   inflating: images/Panda_0018293.jpg
#   inflating: images/Panda_0018294.jpg
#   inflating: images/Panda_0018295.jpg
#   inflating: images/Panda_0018296.jpg
#   inflating: images/Panda_0018298.jpg
#   inflating: images/Panda_0018307.jpg
#   inflating: images/Panda_0018308.jpg
#   inflating: images/Panda_0018310.jpg
#   inflating: images/Panda_0018313.jpg
#   inflating: images/Panda_0018314.jpg
#   inflating: images/Panda_0018316.jpg
#   inflating: images/Panda_0018322.jpg
#   inflating: images/Panda_0018324.jpg
#   inflating: images/Panda_0018335.jpg
#   inflating: images/Panda_0018338.jpg
#   inflating: images/Panda_0018339.jpg
#   inflating: images/Panda_0018361.jpg
#   inflating: images/Panda_0018362.jpg
#   inflating: images/Panda_0018363.jpg
#   inflating: images/Panda_0018375.jpg
#   inflating: images/Panda_0018376.jpg
#   inflating: images/Panda_0018377.jpg
#   inflating: images/Panda_0018379.jpg
#   inflating: images/Panda_0018389.jpg
#   inflating: images/Panda_0018391.jpg
#   inflating: images/Panda_0018392.jpg
#   inflating: images/Panda_0018395.jpg
#   inflating: images/Panda_0018412.jpg
#   inflating: images/Panda_0018418.jpg
#   inflating: images/Panda_0018420.jpg
#   inflating: images/Panda_0018421.jpg
#   inflating: images/Panda_0018423.jpg
#   inflating: images/Panda_0018425.jpg
#   inflating: images/Panda_0018451.jpg
#   inflating: images/Panda_0018456.jpg
#   inflating: images/Panda_0018457.jpg
#   inflating: images/Panda_0018465.jpg
#   inflating: images/Panda_0018480.jpg
#   inflating: images/Panda_0018483.jpg
#   inflating: images/Panda_0018486.jpg
#   inflating: images/Panda_0018487.jpg
#   inflating: images/Panda_0018488.jpg
#   inflating: images/Panda_0018492.jpg
#   inflating: images/Panda_0018500.jpg
#   inflating: images/Panda_0018503.jpg
#   inflating: images/Panda_0018506.jpg
#   inflating: images/Panda_0018512.jpg
#   inflating: images/Panda_0018514.jpg
#   inflating: images/Panda_0018521.jpg
#   inflating: images/Panda_0018530.jpg
#   inflating: images/Panda_0018533.jpg
#   inflating: images/Panda_0018543.jpg
#   inflating: images/Panda_0018568.jpg
#   inflating: images/Panda_0018577.jpg
#   inflating: images/Panda_0018579.jpg
#   inflating: images/Panda_0018598.jpg
#   inflating: images/Panda_0018608.jpg
#   inflating: images/Panda_0018626.jpg
#   inflating: images/Panda_0018637.jpg
#   inflating: images/Panda_0018659.jpg
#   inflating: images/Panda_0018668.jpg
#   inflating: images/Panda_0018669.jpg
#   inflating: images/Panda_0018672.jpg
#   inflating: images/Panda_0018673.jpg
#   inflating: images/Panda_0018674.jpg
#   inflating: images/Panda_0018679.jpg
#   inflating: images/Panda_0018680.jpg
#   inflating: images/Panda_0018681.jpg
#   inflating: images/Panda_0018682.jpg
#   inflating: images/Panda_0018683.jpg
#   inflating: images/Panda_0018684.jpg
#   inflating: images/Panda_0018685.jpg
#   inflating: images/Panda_0018686.jpg
#   inflating: images/Panda_0018687.jpg
#   inflating: images/Panda_0018688.jpg
#   inflating: images/Panda_0018689.jpg
#   inflating: images/Panda_0018690.jpg
#   inflating: images/Panda_0018691.jpg
#   inflating: images/Panda_0018692.jpg
#   inflating: images/Panda_0018693.jpg
#   inflating: images/Panda_0018694.jpg
#   inflating: images/Panda_0018695.jpg
#   inflating: images/Panda_0018696.jpg
#   inflating: images/Panda_0018697.jpg
#   inflating: images/Panda_0018698.jpg
#   inflating: images/Panda_0018699.jpg
#   inflating: images/Panda_0018700.jpg
#   inflating: images/Panda_0018712.jpg
#   inflating: images/Panda_0018722.jpg
#   inflating: images/Panda_0018733.jpg
#   inflating: images/Panda_0018734.jpg
#   inflating: images/Panda_0018735.jpg
#   inflating: images/Panda_0018736.jpg
#   inflating: images/Panda_0018737.jpg
#   inflating: images/Panda_0018738.jpg
#   inflating: images/Panda_0018739.jpg
#   inflating: images/Panda_0018740.jpg
#   inflating: images/Panda_0018741.jpg
#   inflating: images/Panda_0018742.jpg
#   inflating: images/Panda_0018743.jpg
#   inflating: images/Panda_0018744.jpg
#   inflating: images/Panda_0018745.jpg
#   inflating: images/Panda_0018748.jpg
#   inflating: images/Panda_0018749.jpg
#   inflating: images/Panda_0018750.jpg
#   inflating: images/Panda_0018759.jpg
#   inflating: images/Panda_0018767.jpg
#   inflating: images/Panda_0018781.jpg
#   inflating: images/Panda_0018793.jpg
#   inflating: images/Panda_0018796.jpg
#   inflating: images/Panda_0018797.jpg
#   inflating: images/Panda_0018801.jpg
#   inflating: images/Panda_0018802.jpg
#   inflating: images/Panda_0018803.jpg
#   inflating: images/Panda_0018807.jpg
#   inflating: images/Panda_0018816.jpg
#   inflating: images/Panda_0018823.jpg
#   inflating: images/Panda_0018824.jpg
#   inflating: images/Panda_0018830.jpg
#   inflating: images/Panda_0018844.jpg
#   inflating: images/Panda_0018846.jpg
#   inflating: images/Panda_0018848.jpg
#   inflating: images/Panda_0018849.jpg
#   inflating: images/Panda_0018856.jpg
#   inflating: images/Panda_0018859.jpg
#   inflating: images/Panda_0018876.jpg
#   inflating: images/Panda_0018893.jpg
#   inflating: images/Panda_0018895.jpg
#   inflating: images/Panda_0018899.jpg
#   inflating: images/Panda_0018906.jpg
#   inflating: images/Panda_0018944.jpg
#   inflating: images/Panda_0018951.jpg
#   inflating: images/Panda_0018969.jpg
#   inflating: images/Panda_0018986.jpg
#   inflating: images/Panda_0018996.jpg
#   inflating: images/Panda_0019004.jpg
#   inflating: images/Panda_0019006.jpg
#   inflating: images/Panda_0019010.jpg
#   inflating: images/Panda_0019011.jpg
#   inflating: images/Panda_0019059.jpg
#   inflating: images/Panda_0019072.jpg
#   inflating: images/Panda_0019083.jpg
#   inflating: images/Panda_0019086.jpg
#   inflating: images/Panda_0019090.jpg
#   inflating: images/Panda_0019095.jpg
#   inflating: images/Panda_0019120.jpg
#   inflating: images/Panda_0019122.jpg
#   inflating: images/Panda_0019130.jpg
#   inflating: images/Panda_0019134.jpg
#   inflating: images/Panda_0019142.jpg
#   inflating: images/Panda_0019175.jpg
#   inflating: images/Panda_0019199.jpg
#   inflating: images/Panda_0019202.jpg
#   inflating: images/Panda_0019203.jpg
#   inflating: images/Panda_0019215.jpg
#   inflating: images/Panda_0019221.jpg
#   inflating: images/Panda_0019223.jpg
#   inflating: images/Panda_0019232.jpg
#   inflating: images/Panda_0019246.jpg
#   inflating: images/Panda_0019248.jpg
#   inflating: images/Panda_0019253.jpg
#   inflating: images/Panda_0019267.jpg
#   inflating: images/Panda_0019269.jpg
#   inflating: images/Panda_0019271.jpg
#   inflating: images/Panda_0019275.jpg
#   inflating: images/Panda_0019278.jpg
#   inflating: images/Panda_0019283.jpg
#   inflating: images/Panda_0019284.jpg
#   inflating: images/Panda_0019285.jpg
#   inflating: images/Panda_0019290.jpg
#   inflating: images/Panda_0019299.jpg
#   inflating: images/Panda_0019300.jpg
#   inflating: images/Panda_0019310.jpg
#   inflating: images/Panda_0019313.jpg
#   inflating: images/Panda_0019317.jpg
#   inflating: images/Panda_0019321.jpg
#   inflating: images/Panda_0019326.jpg
#   inflating: images/Panda_0019332.jpg
#   inflating: images/Panda_0019352.jpg
#   inflating: images/Panda_0019353.jpg
#   inflating: images/Panda_0019354.jpg
#   inflating: images/Panda_0019358.jpg
#   inflating: images/Panda_0019360.jpg
#   inflating: images/Panda_0019393.jpg
#   inflating: images/Panda_0019397.jpg
#   inflating: images/Panda_0019430.jpg
#   inflating: images/Panda_0019457.jpg
#   inflating: images/Panda_0019463.jpg
#   inflating: images/Panda_0019464.jpg
#   inflating: images/Panda_0019467.jpg
#   inflating: images/Panda_0019468.jpg
#   inflating: images/Panda_0019500.jpg
#   inflating: images/Panda_0019508.jpg
#   inflating: images/Panda_0019522.jpg
#   inflating: images/Panda_0019523.jpg
#   inflating: images/Panda_0019534.jpg
#   inflating: images/Panda_0019542.jpg
#   inflating: images/Panda_0019543.jpg
#   inflating: images/Panda_0019547.jpg
#   inflating: images/Panda_0019555.jpg
#   inflating: images/Panda_0019556.jpg
#   inflating: images/Panda_0019557.jpg
#   inflating: images/Panda_0019558.jpg
#   inflating: images/Panda_0019559.jpg
#   inflating: images/Panda_0019560.jpg
#   inflating: images/Panda_0019563.jpg
#   inflating: images/Panda_0019565.jpg
#   inflating: images/Panda_0019572.jpg
#   inflating: images/Panda_0019573.jpg
#   inflating: images/Panda_0019574.jpg
#   inflating: images/Panda_0019576.jpg
#   inflating: images/Panda_0019578.jpg
#   inflating: images/Panda_0019579.jpg
#   inflating: images/Panda_0019587.jpg
#   inflating: images/Panda_0019593.jpg
#   inflating: images/Panda_0019618.jpg
#   inflating: images/Panda_0019619.jpg
#   inflating: images/Panda_0019631.jpg
#   inflating: images/Panda_0019635.jpg
#   inflating: images/Panda_0019636.jpg
#   inflating: images/Panda_0019646.jpg
#   inflating: images/Panda_0019649.jpg
#   inflating: images/Panda_0019650.jpg
#   inflating: images/Panda_0019659.jpg
#   inflating: images/Panda_0019673.jpg
#   inflating: images/Panda_0019676.jpg
#   inflating: images/Panda_0019677.jpg
#   inflating: images/Panda_0019678.jpg
#   inflating: images/Panda_0019679.jpg
#   inflating: images/Panda_0019681.jpg
#   inflating: images/Panda_0019682.jpg
#   inflating: images/Panda_0019683.jpg
#   inflating: images/Panda_0019684.jpg
#   inflating: images/Panda_0019685.jpg
#   inflating: images/Panda_0019686.jpg
#   inflating: images/Panda_0019687.jpg
#   inflating: images/Panda_0019689.jpg
#   inflating: images/Panda_0019690.jpg
#   inflating: images/Panda_0019691.jpg
#   inflating: images/Panda_0019692.jpg
#   inflating: images/Panda_0019730.jpg
#   inflating: images/Panda_0019732.jpg
#   inflating: images/Panda_0019733.jpg
#   inflating: images/Panda_0019736.jpg
#   inflating: images/Panda_0019739.jpg
#   inflating: images/Panda_0019740.jpg
#   inflating: images/Panda_0019751.jpg
#   inflating: images/Panda_0019775.jpg
#   inflating: images/Panda_0019787.jpg
#   inflating: images/Panda_0019801.jpg
#   inflating: images/Panda_0019802.jpg
#   inflating: images/Panda_0019803.jpg
#   inflating: images/Panda_0019811.jpg
#   inflating: images/Panda_0019815.jpg
#   inflating: images/Panda_0019817.jpg
#   inflating: images/Panda_0019832.jpg
#   inflating: images/Panda_0019834.jpg
#   inflating: images/Panda_0019836.jpg
#   inflating: images/Panda_0019839.jpg
#   inflating: images/Panda_0019877.jpg
#   inflating: images/Panda_0019878.jpg
#   inflating: images/Panda_0019881.jpg
#   inflating: images/Panda_0019884.jpg
#   inflating: images/Panda_0019885.jpg
#   inflating: images/Panda_0019888.jpg
#   inflating: images/Panda_0019918.jpg
#   inflating: images/Panda_0019923.jpg
#   inflating: images/Panda_0019965.jpg
#   inflating: images/Panda_0019969.jpg
#   inflating: images/Panda_0019974.jpg
#   inflating: images/Panda_0019976.jpg
#   inflating: images/Panda_0019977.jpg
#   inflating: images/Panda_0019980.jpg
#   inflating: images/Panda_0019983.jpg
#   inflating: metadata.csv

# %% [markdown]
# # **2. Attention Mechanism**

# %% [markdown]
# ## 2.1 Self-Attention

# %%
class SelfAttention(nn.Module):
    def __init__(self, num_attn_heads, hidden_dim, in_proj_bias=True, out_proj_bias=True):
        super().__init__()
        self.num_heads = num_attn_heads
        self.head_size = hidden_dim // num_attn_heads

        self.qkv_proj = nn.Linear(hidden_dim, 3 * hidden_dim, bias=in_proj_bias)
        self.output_proj = nn.Linear(hidden_dim, hidden_dim, bias=out_proj_bias)

    def forward(self, features, use_causal_mask=False):
        b, s, d = features.shape

        qkv_combined = self.qkv_proj(features)
        q_mat, k_mat, v_mat = torch.chunk(qkv_combined, 3, dim=-1)

        q_mat = q_mat.view(b, s, self.num_heads, self.head_size).permute(0, 2, 1, 3)
        k_mat = k_mat.view(b, s, self.num_heads, self.head_size).permute(0, 2, 1, 3)
        v_mat = v_mat.view(b, s, self.num_heads, self.head_size).permute(0, 2, 1, 3)

        qk = torch.matmul(q_mat, k_mat.transpose(-2, -1))
        sqrt_qk = qk / math.sqrt(self.head_size)

        if use_causal_mask:
            causal_mask = torch.triu(torch.ones_like(sqrt_qk, dtype=torch.bool), diagonal=1)
            sqrt_qk = sqrt_qk.masked_fill(causal_mask, -torch.inf)

        attn_weights = torch.softmax(sqrt_qk, dim=-1)
        attn_values = torch.matmul(attn_weights, v_mat)

        attn_values = attn_values.permute(0, 2, 1, 3).contiguous()
        attn_values = attn_values.view(b, s, d)

        final_output = self.output_proj(attn_values)
        return final_output

# %% [markdown]
# ## 2.2 Cross-Attention

# %%
class CrossAttention(nn.Module):
    def __init__(self, num_attn_heads, query_dim, context_dim, in_proj_bias=True, out_proj_bias=True):
        super().__init__()
        self.num_heads = num_attn_heads
        self.head_size = query_dim // num_attn_heads

        self.query_map = nn.Linear(query_dim, query_dim, bias=in_proj_bias)
        self.key_map = nn.Linear(context_dim, query_dim, bias=in_proj_bias)
        self.value_map = nn.Linear(context_dim, query_dim, bias=in_proj_bias)

        self.output_map = nn.Linear(query_dim, query_dim, bias=out_proj_bias)

    def forward(self, query_input, context_input):
        b_q, s_q, d_q = query_input.shape
        _, s_kv, _ = context_input.shape

        q_mat = self.query_map(query_input)
        k_mat = self.key_map(context_input)
        v_mat = self.value_map(context_input)

        q_mat = q_mat.view(b_q, s_q, self.num_heads, self.head_size).permute(0, 2, 1, 3)
        k_mat = k_mat.view(b_q, s_kv, self.num_heads, self.head_size).permute(0, 2, 1, 3)
        v_mat = v_mat.view(b_q, s_kv, self.num_heads, self.head_size).permute(0, 2, 1, 3)

        qk = torch.matmul(q_mat, k_mat.transpose(-2, -1))
        sqrt_qk = qk / math.sqrt(self.head_size)
        attn_weights = torch.softmax(sqrt_qk, dim=-1)

        attn_values = torch.matmul(attn_weights, v_mat)
        attn_values = attn_values.permute(0, 2, 1, 3).contiguous()
        attn_values = attn_values.view(b_q, s_q, d_q)

        final_output = self.output_map(attn_values)
        return final_output

# %% [markdown]
# # **3. Stable Diffusion**

# %% [markdown]
# ## **3.1 DDPM - Denoising Diffusion Probabilistic Model**

# %%
class DDPMScheduler:
    def __init__(
        self,
        random_generator,
        train_timesteps=1000,
        diffusion_beta_start=0.00085,
        diffusion_beta_end=0.012
    ):

        self.betas = torch.linspace(
            diffusion_beta_start ** 0.5, diffusion_beta_end ** 0.5, train_timesteps,
            dtype=torch.float32) ** 2
        self.alphas = 1.0 - self.betas
        self.alphas_cumulative_product = torch.cumprod(self.alphas, dim=0)
        self.one_val = torch.tensor(1.0)
        self.prng_generator = random_generator
        self.total_train_timesteps = train_timesteps
        self.schedule_timesteps = torch.from_numpy(np.arange(0, train_timesteps)[::-1].copy())

    def set_steps(self, num_sampling_steps=50):
        self.num_sampling_steps = num_sampling_steps
        step_scaling_factor = self.total_train_timesteps // self.num_sampling_steps
        timesteps_for_sampling = (
            np.arange(0, num_sampling_steps) * step_scaling_factor
        ).round()[::-1].copy().astype(np.int64)
        self.schedule_timesteps = torch.from_numpy(timesteps_for_sampling)

    def _get_prior_timestep(self, current_timestep):
        previous_t = current_timestep - self.total_train_timesteps // self.num_sampling_steps
        return previous_t

    def _calculate_variance(self, timestep):
        prev_t = self._get_prior_timestep(timestep)
        alpha_cumprod_t = self.alphas_cumulative_product[timestep]
        alpha_cumprod_t_prev = self.alphas_cumulative_product[prev_t] if prev_t >= 0 else self.one_val
        beta_t_current = 1 - alpha_cumprod_t / alpha_cumprod_t_prev
        variance_value = (1 - alpha_cumprod_t_prev) / (1 - alpha_cumprod_t) * beta_t_current
        variance_value = torch.clamp(variance_value, min=1e-20)
        return variance_value

    def adjust_strength(self, strength_level=1):
        initial_step_index = self.num_sampling_steps - int(self.num_sampling_steps * strength_level)
        self.schedule_timesteps = self.schedule_timesteps[initial_step_index:]
        self.start_sampling_step = initial_step_index # Lưu lại bước bắt đầu

    def step(self, current_t, current_latents, model_prediction):
        t = current_t
        prev_t = self._get_prior_timestep(t)

        alpha_cumprod_t = self.alphas_cumulative_product[t]
        alpha_cumprod_t_prev = self.alphas_cumulative_product[prev_t] if prev_t >= 0 else self.one_val
        beta_cumprod_t = 1 - alpha_cumprod_t
        beta_cumprod_t_prev = 1 - alpha_cumprod_t_prev
        alpha_t_current = alpha_cumprod_t / alpha_cumprod_t_prev
        beta_t_current = 1 - alpha_t_current

        predicted_original = (current_latents - beta_cumprod_t ** 0.5 * model_prediction) / alpha_cumprod_t ** 0.5

        original_coeff = (alpha_cumprod_t_prev ** 0.5 * beta_t_current) / beta_cumprod_t
        current_coeff = alpha_t_current ** 0.5 * beta_cumprod_t_prev / beta_cumprod_t

        predicted_prior_mean = original_coeff * predicted_original + current_coeff * current_latents

        variance_term = 0
        if t > 0:
            target_device = model_prediction.device
            noise_component = torch.randn(
                model_prediction.shape,
                generator=self.prng_generator,
                device=target_device,
                dtype=model_prediction.dtype
            )
            variance_term = (self._calculate_variance(t) ** 0.5) * noise_component

        predicted_prior_sample = predicted_prior_mean + variance_term
        return predicted_prior_sample

    def add_noise(self, initial_samples, noise_timesteps):
        alphas_cumprod = self.alphas_cumulative_product.to(
            device=initial_samples.device,
            dtype=initial_samples.dtype
        )
        noise_timesteps = noise_timesteps.to(initial_samples.device)
        sqrt_alpha_cumprod = alphas_cumprod[noise_timesteps] ** 0.5
        sqrt_alpha_cumprod = sqrt_alpha_cumprod.view(
            sqrt_alpha_cumprod.shape[0], *([1] * (initial_samples.ndim - 1))
        )
        sqrt_one_minus_alpha_cumprod = (1 - alphas_cumprod[noise_timesteps]) ** 0.5
        sqrt_one_minus_alpha_cumprod = sqrt_one_minus_alpha_cumprod.view(
            sqrt_one_minus_alpha_cumprod.shape[0], *([1] * (initial_samples.ndim - 1))
        )
        random_noise = torch.randn(
            initial_samples.shape, generator=self.prng_generator,
            device=initial_samples.device, dtype=initial_samples.dtype
        )
        noisy_result = sqrt_alpha_cumprod * initial_samples + sqrt_one_minus_alpha_cumprod * random_noise
        return noisy_result, random_noise

# %% [markdown]
# ## **3.2 UNet Architecture**

# %% [markdown]
# ### 3.2.1 Residual Block

# %%
class UNET_ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, time_dim=1280):
        super().__init__()
        self.gn_feature = nn.GroupNorm(32, in_channels)
        self.conv_feature = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.time_embedding_proj = nn.Linear(time_dim, out_channels)

        self.gn_merged = nn.GroupNorm(32, out_channels)
        self.conv_merged = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)

        if in_channels == out_channels:
            self.residual_connection = nn.Identity()
        else:
            self.residual_connection = nn.Conv2d(in_channels, out_channels, kernel_size=1, padding=0)

    def forward(self, input_feature, time_emb):
        residual = input_feature

        h = self.gn_feature(input_feature)
        h = F.silu(h)
        h = self.conv_feature(h)

        time_emb_processed = F.silu(time_emb)
        time_emb_projected = self.time_embedding_proj(time_emb_processed)
        time_emb_projected = time_emb_projected.unsqueeze(-1).unsqueeze(-1)

        merged_feature = h + time_emb_projected
        merged_feature = self.gn_merged(merged_feature)
        merged_feature = F.silu(merged_feature)
        merged_feature = self.conv_merged(merged_feature)

        output = merged_feature + self.residual_connection(residual)
        return output

# %% [markdown]
# ### 3.2.2 Attention Block

# %%
class UNET_AttentionBlock(nn.Module):
    def __init__(self, num_heads, head_dim, context_dim=512):
        super().__init__()
        embed_dim = num_heads * head_dim

        self.gn_in = nn.GroupNorm(32, embed_dim, eps=1e-6)
        self.proj_in = nn.Conv2d(embed_dim, embed_dim, kernel_size=1, padding=0)

        self.ln_1 = nn.LayerNorm(embed_dim)
        self.attn_1 = SelfAttention(num_heads, embed_dim, in_proj_bias=False)
        self.ln_2 = nn.LayerNorm(embed_dim)
        self.attn_2 = CrossAttention(num_heads, embed_dim, context_dim, in_proj_bias=False)
        self.ln_3 = nn.LayerNorm(embed_dim)

        self.ffn_geglu = nn.Linear(embed_dim, 4 * embed_dim * 2)
        self.ffn_out = nn.Linear(4 * embed_dim, embed_dim)
        self.proj_out = nn.Conv2d(embed_dim, embed_dim, kernel_size=1, padding=0)

    def forward(self, input_tensor, context_tensor):
        skip_connection = input_tensor

        B, C, H, W = input_tensor.shape
        HW = H * W

        h = self.gn_in(input_tensor)
        h = self.proj_in(h)
        h = h.view(B, C, HW).transpose(-1, -2)

        attn1_skip = h
        h = self.ln_1(h)
        h = self.attn_1(h)
        h = h + attn1_skip

        attn2_skip = h
        h = self.ln_2(h)
        h = self.attn_2(h, context_tensor)
        h = h + attn2_skip

        ffn_skip = h
        h = self.ln_3(h)
        intermediate, gate = self.ffn_geglu(h).chunk(2, dim=-1)
        h = intermediate * F.gelu(gate)
        h = self.ffn_out(h)
        h = h + ffn_skip

        h = h.transpose(-1, -2).view(B, C, H, W)
        output = self.proj_out(h) + skip_connection
        return output

# %%
class Upsample(nn.Module):
    def __init__(self, num_channels):
        super().__init__()
        self.conv = nn.Conv2d(num_channels, num_channels, kernel_size=3, padding=1)

    def forward(self, feature_map):
        x = F.interpolate(feature_map, scale_factor=2, mode='nearest')
        x = self.conv(x)
        return x


class SwitchSequential(nn.Sequential):
    def forward(self, x, guidance_context, time_embedding):
        for module_instance in self:
            if isinstance(module_instance, UNET_AttentionBlock):
                x = module_instance(x, guidance_context)
            elif isinstance(module_instance, UNET_ResidualBlock):
                x = module_instance(x, time_embedding)
            else:
                x = module_instance(x)
        return x


class TimeEmbedding(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.proj1 = nn.Linear(n_embd, 4 * n_embd)
        self.proj2 = nn.Linear(4 * n_embd, 4 * n_embd)

    def forward(self, x):
        x = self.proj1(x)
        x = F.silu(x)
        x = self.proj2(x)
        return x

# %%
class UNET(nn.Module):
    def __init__(self, h_dim, n_head):
        super().__init__()

        self.down_blocks = nn.ModuleList([
            SwitchSequential(nn.Conv2d(4, h_dim, kernel_size=3, padding=1)),
            SwitchSequential(
                UNET_ResidualBlock(h_dim, h_dim),
                UNET_AttentionBlock(n_head, (h_dim)//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(h_dim, h_dim),
                UNET_AttentionBlock(n_head, (h_dim)//n_head)
            ),
            SwitchSequential(nn.Conv2d(h_dim, h_dim, kernel_size=3, stride=2, padding=1)),
            SwitchSequential(
                UNET_ResidualBlock(h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head)
            ),
            SwitchSequential(nn.Conv2d(2*h_dim, 2*h_dim, kernel_size=3, stride=2, padding=1)),
            SwitchSequential(UNET_ResidualBlock(2*h_dim, 4*h_dim)),
            SwitchSequential(UNET_ResidualBlock(4*h_dim, 4*h_dim)),
        ])

        self.mid_block = SwitchSequential(
            UNET_ResidualBlock(4*h_dim, 4*h_dim),
            UNET_AttentionBlock(n_head, (4*h_dim)//n_head),
            UNET_ResidualBlock(4*h_dim, 4*h_dim),
        )

        self.up_blocks = nn.ModuleList([
            SwitchSequential(UNET_ResidualBlock(4*h_dim + 4*h_dim, 4*h_dim)),
            SwitchSequential(UNET_ResidualBlock(4*h_dim + 4*h_dim, 4*h_dim)),
            SwitchSequential(
                UNET_ResidualBlock(4*h_dim + 2*h_dim, 4*h_dim),
                Upsample(4*h_dim)
            ),
            SwitchSequential(
                UNET_ResidualBlock(4*h_dim + 2*h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(4*h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim + h_dim, 2*h_dim),
                UNET_AttentionBlock(n_head, (2*h_dim)//n_head),
                Upsample(2*h_dim)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim + h_dim, h_dim),
                UNET_AttentionBlock(n_head, h_dim//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim, h_dim),
                UNET_AttentionBlock(n_head, h_dim//n_head)
            ),
            SwitchSequential(
                UNET_ResidualBlock(2*h_dim, h_dim),
                UNET_AttentionBlock(n_head, h_dim//n_head)
            ),
        ])

    def forward(self, latent_input, context_embedding, time_embedding):
        down_block_residuals = []
        current_feature_map = latent_input

        for block in self.down_blocks:
            current_feature_map = block(
                current_feature_map,
                context_embedding,
                time_embedding
            )
            down_block_residuals.append(current_feature_map)

        current_feature_map = self.mid_block(
            current_feature_map,
            context_embedding,
            time_embedding
        )

        for block in self.up_blocks:
            residual = down_block_residuals.pop()
            current_feature_map = torch.cat((current_feature_map, residual), dim=1)
            current_feature_map = block(
                current_feature_map,
                context_embedding,
                time_embedding
            )

        return current_feature_map


class UNETOutputLayer(nn.Module):
    def __init__(self, input_channels, output_channels):
        super().__init__()
        self.final_groupnorm = nn.GroupNorm(32, input_channels)
        self.final_conv = nn.Conv2d(input_channels, output_channels, kernel_size=3, padding=1)

    def forward(self, feature_map):
        norm_map = self.final_groupnorm(feature_map)
        activated_map = F.silu(norm_map)
        output_map = self.final_conv(activated_map)

        return output_map

# %% [markdown]
# ## **3.3 Timestep Handling**

# %%
def embed_a_timestep(timestep, embedding_dim=320):
    half_dim = embedding_dim // 2
    freqs = torch.exp(-math.log(10000) *
                      torch.arange(start=0, end=half_dim, dtype=torch.float32) /
                      half_dim)
    x = torch.tensor([timestep], dtype=torch.float32)[:, None] * freqs[None]
    return torch.cat([torch.cos(x), torch.sin(x)], dim=-1)

def embed_timesteps(timesteps, embedding_dim=320):
    half_dim = embedding_dim // 2
    freqs = torch.exp(-math.log(10000) *
                      torch.arange(half_dim, dtype=torch.float32) /
                      half_dim).to(device=timesteps.device)
    args = timesteps[:, None].float() * freqs[None, :]
    return torch.cat([torch.cos(args), torch.sin(args)], dim=-1)

# %% [markdown]
# ## **3.4 Diffusion Process**

# %%
class Diffusion(nn.Module):
    def __init__(self, h_dim=128, n_head=4):
        super().__init__()
        self.time_embedding = TimeEmbedding(320)
        self.unet = UNET(h_dim, n_head)
        self.unet_output = UNETOutputLayer(h_dim, 4)

    @torch.autocast(
        device_type='cuda', dtype=torch.float16,
        enabled=True, cache_enabled=True
    )
    def forward(self, latent, context, time):
        time = self.time_embedding(time)
        output = self.unet(latent, context, time)
        output = self.unet_output(output)
        return output

# %% [markdown]
# ## **3.5 CLIP - Contrastive Language-Image Pre-Training**

# %%
class CLIPTextEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        CLIP_id = "openai/clip-vit-base-patch32"
        self.tokenizer = CLIPTokenizer.from_pretrained(CLIP_id)
        self.text_encoder = CLIPTextModel.from_pretrained(CLIP_id)
        self.device = "cuda" if torch.cuda.is_available() else "cpu"

        for param in self.text_encoder.parameters():
            param.requires_grad = False

        self.text_encoder.eval()
        self.text_encoder.to(self.device)

    def forward(self, prompts):
        inputs = self.tokenizer(
            prompts,
            padding="max_length",
            truncation=True,
            max_length=self.text_encoder.config.max_position_embeddings,
            return_tensors="pt"
        )
        input_ids = inputs.input_ids.to(self.device)
        attention_mask = inputs.attention_mask.to(self.device)

        with torch.no_grad():
            text_encoder_output = self.text_encoder(
                input_ids=input_ids,
                attention_mask=attention_mask
            )
        last_hidden_states = text_encoder_output.last_hidden_state

        return last_hidden_states

# %% [markdown]
# ## **3.6. VAE - Variational Autoencoder**

# %%
VAE_id = "stabilityai/sd-vae-ft-mse"
vae = AutoencoderKL.from_pretrained(VAE_id)
vae.requires_grad_(False)
vae.eval()
# Out:
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# AutoencoderKL(
#   (encoder): Encoder(
#     (conv_in): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (down_blocks): ModuleList(
#       (0): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0-1): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (1): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (2): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (3): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0-1): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#       )
#     )
#     (mid_block): UNetMidBlock2D(
#       (attentions): ModuleList(
#         (0): Attention(
#           (group_norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (to_q): Linear(in_features=512, out_features=512, bias=True)
#           (to_k): Linear(in_features=512, out_features=512, bias=True)
#           (to_v): Linear(in_features=512, out_features=512, bias=True)
#           (to_out): ModuleList(
#             (0): Linear(in_features=512, out_features=512, bias=True)
#             (1): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#     )
#     (conv_norm_out): GroupNorm(32, 512, eps=1e-06, affine=True)
#     (conv_act): SiLU()
#     (conv_out): Conv2d(512, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (decoder): Decoder(
#     (conv_in): Conv2d(4, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (up_blocks): ModuleList(
#       (0-1): 2 x UpDecoderBlock2D(
#         (resnets): ModuleList(
#           (0-2): 3 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (upsamplers): ModuleList(
#           (0): Upsample2D(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (2): UpDecoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (upsamplers): ModuleList(
#           (0): Upsample2D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (3): UpDecoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#       )
#     )
#     (mid_block): UNetMidBlock2D(
#       (attentions): ModuleList(
#         (0): Attention(
#           (group_norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (to_q): Linear(in_features=512, out_features=512, bias=True)
#           (to_k): Linear(in_features=512, out_features=512, bias=True)
#           (to_v): Linear(in_features=512, out_features=512, bias=True)
#           (to_out): ModuleList(
#             (0): Linear(in_features=512, out_features=512, bias=True)
#             (1): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#     )
#     (conv_norm_out): GroupNorm(32, 128, eps=1e-06, affine=True)
#     (conv_act): SiLU()
#     (conv_out): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (quant_conv): Conv2d(8, 8, kernel_size=(1, 1), stride=(1, 1))
#   (post_quant_conv): Conv2d(4, 4, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# # **4. Utility Functions**

# %%
def show_images(images, title="", titles=[]):
    plt.figure(figsize=(8, 8))
    for i in range(min(25, len(images))):
        plt.subplot(5, 5, i+1)
        img = images[i].permute(1, 2, 0).cpu().numpy()
        plt.imshow(img)
        if titles:
            plt.title(titles[i])
        plt.axis('off')
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()


def rescale(value, in_range, out_range, clamp=False):
    in_min, in_max = in_range
    out_min, out_max = out_range

    in_span = in_max - in_min
    out_span = out_max - out_min

    scaled_value = (value - in_min) / (in_span + 1e-8)
    rescaled_value = out_min + (scaled_value * out_span)

    if clamp:
        rescaled_value = torch.clamp(
            rescaled_value,
            out_min, out_max
        )

    return rescaled_value

# %% [markdown]
# # **5. Dataset Preparation**

# %%
WIDTH, HEIGHT = 32, 32
batch_size = 32

class EmojiDataset(Dataset):
    def __init__(self, csv_files, image_folder, transform=None):
        self.dataframe = pd.concat([pd.read_csv(csv_file) for csv_file in csv_files])
        self.images_folder = image_folder
        self.dataframe['image_path'] = self.dataframe['file_name'].str.replace('\\', '/')
        self.image_paths = self.dataframe['image_path'].tolist()
        self.titles = self.dataframe['prompt'].tolist()
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        image_path = self.images_folder + '/' + self.image_paths[idx]
        title = self.titles[idx]
        title = title.replace('"', '').replace("'", '')
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, title

transform = transforms.Compose([
    transforms.Resize(
        (WIDTH, HEIGHT),
        interpolation=transforms.InterpolationMode.BICUBIC
    ),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

csv_files = ['/kaggle/working/metadata.csv']
image_folder = '/kaggle/working/images'

train_dataset = EmojiDataset(
    csv_files=csv_files,
    image_folder=image_folder,
    transform=transform
)
train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    persistent_workers=True
)

dataiter = iter(train_dataloader)
images, titles = next(dataiter)

print(f"Batch images shape: {images.shape}")

clipped_images = torch.clamp(images, 0, 1)
plt.figure(figsize=(8, 8))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(clipped_images[i].permute(1, 2, 0).numpy())
    print(titles[i])
    plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Batch images shape: torch.Size([32, 3, 32, 32])
# ARedPandaBlush emoji with a round head, large round eyes, slightly open mouth, blush expression, reddish-brown skin color, no action, with a white background.
# Corp_pandamonch2 emoji with a round head, small eyes, closed mouth, neutral expression, light brown skin color, holding a phone, with a white background.
# Panda Run Hug emoji with a round head, large black eyes, open mouth showing teeth, excited expression, light brown skin color, running action, with a white background.
# AngryThirstyDuckPanda emoji with a round head, black and white eyes, open mouth showing teeth, angry expression, yellow skin color, holding a sword and drinking from a straw, with a white background.
# Panda angry emoji with a round head, small eyes, wide open mouth showing teeth, angry expression, light brown skin color, no action, with a white background.
# Pandaevil emoji with a round head, large black eyes, wide open mouth, angry expression, red skin color, no action, with a white background.
# Panda emoji with a round head, large round eyes, wide open mouth, surprised expression, white skin color, no action, with a white background.
# Wink_panda emoji with a round head, small eyes, smiling mouth, happy expression, brown skin color, no action, with a white background.
# Pandacool emoji with a round head, large eyes, wide open mouth, surprised expression, light brown skin color, no action, with a white background.
# PandaPing emoji with a round head, large black eyes, wide open mouth, surprised expression, light brown skin color, no action, with a white background.
# PandaLove emoji with a round head, small black eyes, smiling mouth, happy expression, white skin color, holding a pink heart, with a white background.
# Char_redpanda_pinkresources emoji with a round head, large black eyes, small mouth, neutral expression, pink skin color, holding a gun, with a white background.
# G_pandagun emoji with a round head, black eyes, open mouth showing teeth, angry expression, white skin color, holding a gun in its right hand, with a white background.
# Pandacry_F emoji with a rounded head, small eyes, slightly open mouth, sad expression, light brown skin color, no action, with a white background.
# Electrical Panda emoji with a round head, large black eyes, wide open mouth, surprised expression, reddish-brown skin color, holding a red wire, with a white background.
# Pandasquishy emoji with a round head, small eyes, squished mouth, surprised expression, pink skin color, no action, with a white background.
# PandaBoyAngry emoji with a round head, small eyes, open mouth showing teeth, angry expression, light brown skin color, fists clenched in front of him, with a white background.
# Im sorry, but I cant assist with that request.
# Panda dance emoji with a round head, large black eyes, small open mouth, playful expression, light brown skin color, dancing action, with a white background.
# WAPandaHype emoji with a round head, large black eyes, wide open mouth, excited expression, white skin color, no action, with a white background.
# Pandawelcome emoji with a round head, large eyes, wide open mouth, surprised expression, white skin color, holding a sign, with a white background.
# CryPanda emoji with a round head, large teardrop-shaped eyes, wide open mouth showing teeth, distressed expression, white skin color, no action, with a white background.
# Groomerpanda emoji with a round head, large round eyes, small open mouth, neutral expression, brown fur, holding a comb, with a white background.
# PandaRich emoji with a round head, large black sunglasses covering eyes, wide open mouth showing teeth, angry expression, dark skin color, holding a money bag, with a white background.
# Panda_sadge3 emoji with a round head, small black eyes, smiling mouth, happy expression, light brown skin color, no action, with a white background.

# %% [markdown]
# # **6. Model Training**

# %%
def train(diffusion, vae, text_encoder, scheduler,
          optimizer, lr_scheduler, scaler,
          criterion, dataloader, num_epochs, device="cuda"):
    losses = []
    for epoch in range(num_epochs):
        diffusion.train()

        epoch_loss = 0.0
        progress_bar = tqdm(dataloader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False)

        for batch_idx, (images, titles) in enumerate(progress_bar):
            images = images.to(device)
            image_titles = [f"A photo of {title}" for title in titles]
            # 50% image_titles là chuỗi rỗng
            image_titles = [title if random.random() < 0.5 else "" for title in image_titles]

            with torch.no_grad():
                latents = vae.encode(images).latent_dist.sample() * 0.18215

            timesteps = torch.randint(
                0, scheduler.total_train_timesteps,
                 (latents.shape[0],), device=device
            )

            noisy_latents, noise = scheduler.add_noise(latents, timesteps)
            time_embeddings = embed_timesteps(timesteps).to(device)
            text_embeddings = text_encoder(image_titles)

            noise_pred = diffusion(noisy_latents, text_embeddings, time_embeddings)

            with autocast(device_type='cuda', dtype=torch.float16,
                          enabled=True, cache_enabled=True):
                loss = criterion(noise_pred, noise)

            optimizer.zero_grad()
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            batch_loss = loss.item()
            epoch_loss += batch_loss

            progress_bar.set_postfix(loss=f"{batch_loss:.5f}",
                                     lr=f"{optimizer.param_groups[0]['lr']:.6f}")

        lr_scheduler.step()
        avg_epoch_loss = epoch_loss / len(dataloader)
        if (epoch + 1) % 10 == 0 or epoch == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}] - Avg Loss: {avg_epoch_loss:.5f}")
        losses.append(avg_epoch_loss)

    print("Training finished!")
    return losses

# %%
EPOCHS = 300

h_dim = 384
n_head = 8

vae = vae.to(device)
diffusion = Diffusion(h_dim, n_head).to(device)
clip = CLIPTextEncoder().to(device)

random_generator = torch.Generator(device='cuda')
noise_scheduler = DDPMScheduler(random_generator)

optimizer = torch.optim.AdamW(diffusion.parameters(), lr=1e-4)
criterion = torch.nn.MSELoss()

lrate_scheduler = lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=EPOCHS, eta_min=1e-5
)
scaler = GradScaler()

def count_parameters(model):
    return sum(p.numel() for p in model.parameters())

vae_params = count_parameters(vae)
diffusion_params = count_parameters(diffusion)
clip_params = count_parameters(clip)

print(f"VAE parameters: {vae_params}")
print(f"Diffusion parameters: {diffusion_params}")
print(f"CLIP parameters: {clip_params}")
print(f"Total parameters: {vae_params + diffusion_params + clip_params}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# VAE parameters: 83653863
# Diffusion parameters: 631718020
# CLIP parameters: 63165952
# Total parameters: 778537835

# %%
losses = train(diffusion, vae, clip, noise_scheduler,
               optimizer, lrate_scheduler, scaler,
               criterion, train_dataloader, EPOCHS, device=device)
# Out:
# Epoch 1/300:   0%|          | 0/121 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Epoch [1/300] - Avg Loss: 0.35515
# Epoch [10/300] - Avg Loss: 0.22768
# Epoch [20/300] - Avg Loss: 0.21619
# Epoch [30/300] - Avg Loss: 0.19105
# Epoch [40/300] - Avg Loss: 0.17962
# Epoch [50/300] - Avg Loss: 0.17535
# Epoch [60/300] - Avg Loss: 0.17404
# Epoch [70/300] - Avg Loss: 0.16103
# Epoch [80/300] - Avg Loss: 0.16308
# Epoch [90/300] - Avg Loss: 0.14881
# Epoch [100/300] - Avg Loss: 0.14253
# Epoch [110/300] - Avg Loss: 0.14088
# Epoch [120/300] - Avg Loss: 0.13287
# Epoch [130/300] - Avg Loss: 0.12516
# Epoch [140/300] - Avg Loss: 0.12418
# Epoch [150/300] - Avg Loss: 0.12566
# Epoch [160/300] - Avg Loss: 0.11258
# Epoch [170/300] - Avg Loss: 0.10794
# Epoch [180/300] - Avg Loss: 0.10173
# Epoch [190/300] - Avg Loss: 0.10263
# Epoch [200/300] - Avg Loss: 0.09452
# Epoch [210/300] - Avg Loss: 0.08997
# Epoch [220/300] - Avg Loss: 0.08581
# Epoch [230/300] - Avg Loss: 0.08211
# Epoch [240/300] - Avg Loss: 0.08091
# Epoch [250/300] - Avg Loss: 0.07551
# Epoch [260/300] - Avg Loss: 0.07114
# Epoch [270/300] - Avg Loss: 0.07320
# Epoch [280/300] - Avg Loss: 0.06809
# Epoch [290/300] - Avg Loss: 0.06917
# Epoch [300/300] - Avg Loss: 0.06388
# Training finished!

# %%
plt.figure(figsize=(16, 8))

plt.plot(losses, label='Loss', color='blue')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')

min_loss = min(losses)
min_loss_epoch = losses.index(min_loss)
plt.scatter(min_loss_epoch, min_loss, color='green', zorder=5)
plt.text(min_loss_epoch,
         min_loss+0.025,
         f'{min_loss:.4f}',
         fontsize=12,
         verticalalignment='center',
         horizontalalignment='center',
         color='green')

plt.legend()
plt.grid()
plt.savefig('training_loss.png')
plt.show()

# %% [markdown]
# # **7. Model Checkpointing**

# %%
torch.save(diffusion.state_dict(), "diffusion_model_emoji.pth")
# !zip -r diffusion_model_emoji.zip diffusion_model_emoji.pth
# Out:
#   adding: diffusion_model_emoji.pth (deflated 8%)

# %%
# https://drive.google.com/file/d/1L7NiTeK5veX7A7ynux7vwZjx7b_ta5ur/view?usp=drive_link
# !gdown 1L7NiTeK5veX7A7ynux7vwZjx7b_ta5ur

# %%
h_dim = 384
n_head = 8

VAE_id = "stabilityai/sd-vae-ft-mse"
vae = AutoencoderKL.from_pretrained(VAE_id)
vae.requires_grad_(False)
vae.eval()
vae = vae.to(device)

clip = CLIPTextEncoder().to(device)
clip.eval()

diffusion = Diffusion(h_dim, n_head).to(device)
diffusion.load_state_dict(torch.load("diffusion_model_emoji.pth"))
diffusion.eval()

random_generator = torch.Generator(device='cuda')
noise_scheduler = DDPMScheduler(random_generator)
# Out:
# /tmp/ipykernel_31/1745434495.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   diffusion.load_state_dict(torch.load("diffusion_model_emoji.pth"))

# %% [markdown]
# # **8. Image Generation**

# %%
LATENTS_WIDTH = WIDTH // 8
LATENTS_HEIGHT = HEIGHT // 8

def generate_image(
    prompt,
    diffusion,
    vae,
    text_encoder,
    scheduler,
    num_inference_steps=100,
    seed=None,
    device='cuda' if torch.cuda.is_available() else 'cpu',
):
    rng_generator = torch.Generator(device=device)
    if seed is None:
        rng_generator.seed()
    else:
        rng_generator.manual_seed(seed)

    prompts = [prompt]
    text_embeddings = text_encoder(prompts).to(device)

    scheduler.set_steps(num_inference_steps)

    latent_shape = (1, 4, LATENTS_HEIGHT, LATENTS_WIDTH)

    noisy_latents = torch.randn(
        latent_shape, generator=rng_generator, device=device)
    timesteps = scheduler.schedule_timesteps

    for t in tqdm(timesteps):
        latent_model_input = noisy_latents

        time_embedding = embed_a_timestep(t).to(device)

        with torch.no_grad():
            noise_pred = diffusion(
                latent_model_input,
                text_embeddings,
                time_embedding
            )
        noisy_latents = scheduler.step(
            t,
            noisy_latents,
            noise_pred
        )

    final_latents = noisy_latents / 0.18215

    with torch.no_grad():
        decoded_image_tensor = vae.decode(final_latents).sample

    image_output = rescale(decoded_image_tensor, (-1, 1), (0, 255), clamp=True)
    image_output = image_output.permute(0, 2, 3, 1).to("cpu", torch.uint8).numpy()
    return image_output[0]

# %%
user_inputs = prompts = [
    "a happy panda with sparkling eyes, open mouth showing tongue, black and white fur, floating, purple background",
    "an angry panda with narrowed eyes, frowning mouth, black and white fur, wearing a party hat, white background",
    "a confused panda with wide eyes, slightly open mouth, black and white fur, pointing at its head and wearing a star-shaped crown, dark blue background",
    "a sad panda with droopy eyes, frowning mouth, black and white fur, waving hand and wearing red pom-poms, white background",
    "a grumpy panda with half-closed eyes, frowning mouth, black and white fur, wielding a large knife, red background",
    "a happy panda with teary eyes, smiling mouth, black and white fur, wearing a sombrero, white background",
    "a devilish panda with red eyes, wide open mouth showing tongue, black and white fur, wearing horns and hugging a teddy bear, warm background with a fireplace and autumn leaves",
    "a cozy panda with half-closed eyes, slightly open mouth, black and white fur, holding a steaming cup of coffee and making a fist, warm background with a fireplace and autumn leaves",
    "a surprised panda with wide eyes, open mouth, black and white fur, wearing a purple hoodie and sitting on its hind legs, blue background",
]

fig, axes = plt.subplots(3, 3, figsize=(3, 3))
axes = axes.flatten()
for i, user_input in enumerate(user_inputs[:9]):
    prompt = f"A photo of {user_input.lower()}"
    img = generate_image(prompt, diffusion, vae, clip, noise_scheduler, num_inference_steps=100)
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.02it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.08it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.18it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.18it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.20it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.14it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.16it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.12it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.20it/s]

# %%
user_inputs = [
    "a sad panda with droopy eyes, frowning mouth, black and white fur, sitting under a tree, red background",
    "a sleepy panda with closed eyes, yawning mouth, black and white fur, lying on its back, white background",
    "a curious panda with wide eyes, slightly open mouth, black and white fur, holding a bamboo stick, dark blue background",
    "a happy panda with bright eyes, wide open mouth, black and white fur, climbing a tree, white background",
    "a confused panda with wide eyes, slightly tilted head, black and white fur, wearing a red bow tie, white background",
    "a grumpy panda with half-closed eyes, frowning mouth, black and white fur, sitting in a field of flowers, light blue background with red hearts around",
    "a happy panda with wide open eyes, smiling mouth, black and white fur, sitting on a blue ribbon, white background",
    "a laughing panda with closed eyes, wide open mouth, black and white fur, holding a bamboo leaf, white background",
    "a cool panda with sunglasses, smiling mouth, black and white fur, wearing a leather jacket, purple background",
]

fig, axes = plt.subplots(3, 3, figsize=(3, 3))
axes = axes.flatten()
for i, user_input in enumerate(user_inputs[:9]):
    prompt = f"A photo of {user_input.lower()}"
    img = generate_image(prompt, diffusion, vae, clip, noise_scheduler, num_inference_steps=100)
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.16it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.23it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.13it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.19it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.12it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.18it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.17it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.19it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.19it/s]

# %%
user_inputs = [
    "a sleepy panda with closed eyes, smiling mouth, black and white fur, holding a teddy bear, purple background",
    "an angry panda with wide open eyes, showing teeth, black and white fur, wearing a sombrero, red background",
    "a confused panda with wide eyes, slightly open mouth, black and white fur, holding a sign that says SIMP, dark blue background",
    "a grumpy panda with half-closed eyes, frowning mouth, black and white fur, eating bamboo while wearing a sleeping mask, white background",
    "a heart-eyed panda with heart-shaped eyes, open mouth showing tongue, black and white fur, making a fist, light blue background with red hearts",
    "a sad panda with teary eyes, frowning mouth, black and white fur, wearing sunglasses, black background",
    "a cheerful panda with bright eyes, big smile, black and white fur, sitting on a swing and wearing a rainbow hat, white background",
    "a curious panda with large, round eyes, slightly open mouth, black and white fur, floating and wearing a blue shirt, purple background",
    "a menacing panda with narrowed eyes, open mouth showing teeth, black and white fur, hugging a person while wearing a party hat, blue background",
]

fig, axes = plt.subplots(3, 3, figsize=(3, 3))
axes = axes.flatten()
for i, user_input in enumerate(user_inputs[:9]):
    prompt = f"A photo of {user_input.lower()}"
    img = generate_image(prompt, diffusion, vae, clip, noise_scheduler, num_inference_steps=100)
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.15it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.10it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.17it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.22it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.23it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.19it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.16it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.14it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.17it/s]

# %%
user_inputs = [
    "a grumpy panda with half-closed eyes, smiling mouth, black and white fur, wearing a sombrero, red background",
    "a happy panda with wide eyes, frowning mouth, black and white fur, pointing finger upwards, black background",
    "a sad panda with teary eyes, wide open mouth showing tongue, black and white fur, wearing a party hat, purple background",
    "a confused panda with bright blue eyes, slightly open mouth, black and white fur, holding a large knife, white background",
    "a sleepy panda with closed eyes, big smile, black and white fur, wearing a rainbow hat, dark blue background",
    "an angry panda with narrowed eyes, licking lips, black and white fur, sitting on a swing, warm background with fireplace",
    "a cool panda with sunglasses, frowning mouth, black and white fur, eating bamboo, light blue background with hearts",
    "a devilish panda with red eyes, smiling mouth, black and white fur, holding a steaming cup of coffee, white background",
    "a curious panda with large round eyes, open mouth showing teeth, black and white fur, hugging a teddy bear, red background",
]

fig, axes = plt.subplots(3, 3, figsize=(3, 3))
axes = axes.flatten()
for i, user_input in enumerate(user_inputs[:9]):
    prompt = f"A photo of {user_input.lower()}"
    img = generate_image(prompt, diffusion, vae, clip, noise_scheduler, num_inference_steps=100)
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.22it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.20it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.17it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.20it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.12it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.13it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.18it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.23it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.15it/s]
